# %%
# %matplotlib inline
# %reload_ext autoreload
# %autoreload 2

# %%
import sys, os
import pickle
import imageio
import numpy as np
from skimage import measure

# sys.path.append('../')
# from fastai.conv_learner import *
from fastai.dataset import *

from pathlib import Path
import json
from PIL import ImageDraw, ImageFont
from matplotlib import patches, patheffects

# check to make sure you set the device
# cuda_id = 1
# torch.cuda.set_device(cuda_id)

import pylab as p
from pylab import rcParams
rcParams['figure.figsize'] = 12, 12
rcParams.update({'font.size': 38})
rcParams['lines.linewidth'] = 6
rcParams['legend.loc'] = 'lower left'
rcParams['legend.framealpha'] = 0.5

# %%
############ Useful paths
# path1='data/boxnet/trainingdata/'
# files_list = os.listdir(path1)
# path2 = 'data/boxnet/trainingdata2/'
# path3 = 'data/boxnet/labels/'
path4 = 'data/boxnet/results/'
# PATH = Path('data/boxnet')
# IMAGES = 'trainingdata2'

# %%
version = "23"
# lambda_4a = "0.001"
# lambda_5a = "0.001"
lambda_4b = "0"
lambda_5b = "200.0"
lambda_4c = "1.0"
lambda_5c = "201.0"

# %% [markdown]
# # Generic

# %%
with open(path4+'SSPicker_'+version+'_2b_target_gen_rec2.pickle', 'rb') as handle:
    rec2_2b = pickle.load(handle)
with open(path4+'SSPicker_'+version+'_2b_target_gen_prec2.pickle', 'rb') as handle:
    prec2_2b = pickle.load(handle)
with open(path4+'SSPicker_'+version+'_2b_target_gen_fpr2.pickle', 'rb') as handle:
    fpr2_2b = pickle.load(handle)
with open(path4+'SSPicker_'+version+'_2b_target_gen_rec3.pickle', 'rb') as handle:
    rec3_2b = pickle.load(handle)

lambda_5b = "201.0"
with open(path4+'SSPicker_'+version+'_5b_'+lambda_5b+'_target_gen_rec2.pickle', 'rb') as handle:
    rec2_5b = pickle.load(handle)
with open(path4+'SSPicker_'+version+'_5b_'+lambda_5b+'_target_gen_prec2.pickle', 'rb') as handle:
    prec2_5b = pickle.load(handle)
with open(path4+'SSPicker_'+version+'_5b_'+lambda_5b+'_target_gen_fpr2.pickle', 'rb') as handle:
    fpr2_5b = pickle.load(handle)
with open(path4+'SSPicker_'+version+'_5b_'+lambda_5b+'_target_gen_rec3.pickle', 'rb') as handle:
    rec3_5b = pickle.load(handle)

lambda_5b = "400.0"
with open(path4+'SSPicker_'+version+'_5b_'+lambda_5b+'_target_gen_rec2.pickle', 'rb') as handle:
    rec2_5b_400 = pickle.load(handle)
with open(path4+'SSPicker_'+version+'_5b_'+lambda_5b+'_target_gen_prec2.pickle', 'rb') as handle:
    prec2_5b_400 = pickle.load(handle)
with open(path4+'SSPicker_'+version+'_5b_'+lambda_5b+'_target_gen_fpr2.pickle', 'rb') as handle:
    fpr2_5b_400 = pickle.load(handle)
with open(path4+'SSPicker_'+version+'_5b_'+lambda_5b+'_target_gen_rec3.pickle', 'rb') as handle:
    rec3_5b_400 = pickle.load(handle)

# version = "29_1"    
# lambda_5b = "123.0"
# with open(path4+'SSPicker_'+version+'_5b_'+lambda_5b+'_target_gen_rec2.pickle', 'rb') as handle:
#     rec2_5b_123 = pickle.load(handle)
# with open(path4+'SSPicker_'+version+'_5b_'+lambda_5b+'_target_gen_prec2.pickle', 'rb') as handle:
#     prec2_5b_123 = pickle.load(handle)
# with open(path4+'SSPicker_'+version+'_5b_'+lambda_5b+'_target_gen_fpr2.pickle', 'rb') as handle:
#     fpr2_5b_123 = pickle.load(handle)
# with open(path4+'SSPicker_'+version+'_5b_'+lambda_5b+'_target_gen_rec3.pickle', 'rb') as handle:
#     rec3_5b_123 = pickle.load(handle)


    
version = "29_1"

lambda_5b = "300.1"
with open(path4+'SSPicker_'+version+'_5b_'+lambda_5b+'_target_gen_rec2.pickle', 'rb') as handle:
    rec2_5b_300_1 = pickle.load(handle)
with open(path4+'SSPicker_'+version+'_5b_'+lambda_5b+'_target_gen_prec2.pickle', 'rb') as handle:
    prec2_5b_300_1 = pickle.load(handle)
with open(path4+'SSPicker_'+version+'_5b_'+lambda_5b+'_target_gen_fpr2.pickle', 'rb') as handle:
    fpr2_5b_300_1 = pickle.load(handle)
with open(path4+'SSPicker_'+version+'_5b_'+lambda_5b+'_target_gen_rec3.pickle', 'rb') as handle:
    rec3_5b_300_1 = pickle.load(handle)

lambda_4b = "100.0"
with open(path4+'SSPicker_'+version+'_4b_'+lambda_4b+'_target_gen_rec2.pickle', 'rb') as handle:
    rec2_4b_29_1_boxnet_unmasked = pickle.load(handle)
with open(path4+'SSPicker_'+version+'_4b_'+lambda_4b+'_target_gen_prec2.pickle', 'rb') as handle:
    prec2_4b_29_1_boxnet_unmasked = pickle.load(handle)
with open(path4+'SSPicker_'+version+'_4b_'+lambda_4b+'_target_gen_fpr2.pickle', 'rb') as handle:
    fpr2_4b_29_1_boxnet_unmasked = pickle.load(handle)
with open(path4+'SSPicker_'+version+'_4b_'+lambda_4b+'_target_gen_rec3.pickle', 'rb') as handle:
    rec3_4b_29_1_boxnet_unmasked = pickle.load(handle)

version = "29_1"
lambda_4b = "100.1"
with open(path4+'SSPicker_'+version+'_4b_'+lambda_4b+'_target_gen_rec2.pickle', 'rb') as handle:
    rec2_4b_29_1_boxnet_unmasked2 = pickle.load(handle)
with open(path4+'SSPicker_'+version+'_4b_'+lambda_4b+'_target_gen_prec2.pickle', 'rb') as handle:
    prec2_4b_29_1_boxnet_unmasked2 = pickle.load(handle)
with open(path4+'SSPicker_'+version+'_4b_'+lambda_4b+'_target_gen_fpr2.pickle', 'rb') as handle:
    fpr2_4b_29_1_boxnet_unmasked2 = pickle.load(handle)
with open(path4+'SSPicker_'+version+'_4b_'+lambda_4b+'_target_gen_rec3.pickle', 'rb') as handle:
    rec3_4b_29_1_boxnet_unmasked2 = pickle.load(handle)

lambda_4b = "120.0"
with open(path4+'SSPicker_'+version+'_4b_'+lambda_4b+'_target_gen_rec2.pickle', 'rb') as handle:
    rec2_4b_29_1_boxnet_masked = pickle.load(handle)
with open(path4+'SSPicker_'+version+'_4b_'+lambda_4b+'_target_gen_prec2.pickle', 'rb') as handle:
    prec2_4b_29_1_boxnet_masked = pickle.load(handle)
with open(path4+'SSPicker_'+version+'_4b_'+lambda_4b+'_target_gen_fpr2.pickle', 'rb') as handle:
    fpr2_4b_29_1_boxnet_masked = pickle.load(handle)
with open(path4+'SSPicker_'+version+'_4b_'+lambda_4b+'_target_gen_rec3.pickle', 'rb') as handle:
    rec3_4b_29_1_boxnet_masked = pickle.load(handle)

lambda_4b = "121.0"
with open(path4+'SSPicker_'+version+'_4b_'+lambda_4b+'_target_gen_rec2.pickle', 'rb') as handle:
    rec2_4b_29_1_boxnet_masked2 = pickle.load(handle)
with open(path4+'SSPicker_'+version+'_4b_'+lambda_4b+'_target_gen_prec2.pickle', 'rb') as handle:
    prec2_4b_29_1_boxnet_masked2 = pickle.load(handle)
with open(path4+'SSPicker_'+version+'_4b_'+lambda_4b+'_target_gen_fpr2.pickle', 'rb') as handle:
    fpr2_4b_29_1_boxnet_masked2 = pickle.load(handle)
with open(path4+'SSPicker_'+version+'_4b_'+lambda_4b+'_target_gen_rec3.pickle', 'rb') as handle:
    rec3_4b_29_1_boxnet_masked2 = pickle.load(handle)
    

lambda_4b = "200.0"
with open(path4+'SSPicker_'+version+'_4b_'+lambda_4b+'_target_gen_rec2.pickle', 'rb') as handle:
    rec2_4b_29_1_cryolo_v1 = pickle.load(handle)
with open(path4+'SSPicker_'+version+'_4b_'+lambda_4b+'_target_gen_prec2.pickle', 'rb') as handle:
    prec2_4b_29_1_cryolo_v1 = pickle.load(handle)
with open(path4+'SSPicker_'+version+'_4b_'+lambda_4b+'_target_gen_fpr2.pickle', 'rb') as handle:
    fpr2_4b_29_1_cryolo_v1 = pickle.load(handle)
with open(path4+'SSPicker_'+version+'_4b_'+lambda_4b+'_target_gen_rec3.pickle', 'rb') as handle:
    rec3_4b_29_1_cryolo_v1 = pickle.load(handle)

lambda_4b = "200.2"
with open(path4+'SSPicker_'+version+'_4b_'+lambda_4b+'_target_gen_rec2.pickle', 'rb') as handle:
    rec2_4b_29_1_cryolo_v1_new = pickle.load(handle)
with open(path4+'SSPicker_'+version+'_4b_'+lambda_4b+'_target_gen_prec2.pickle', 'rb') as handle:
    prec2_4b_29_1_cryolo_v1_new = pickle.load(handle)
with open(path4+'SSPicker_'+version+'_4b_'+lambda_4b+'_target_gen_fpr2.pickle', 'rb') as handle:
    fpr2_4b_29_1_cryolo_v1_new = pickle.load(handle)
with open(path4+'SSPicker_'+version+'_4b_'+lambda_4b+'_target_gen_rec3.pickle', 'rb') as handle:
    rec3_4b_29_1_cryolo_v1_new = pickle.load(handle)
    
lambda_4b = "210.0"
with open(path4+'SSPicker_'+version+'_4b_'+lambda_4b+'_target_gen_rec2.pickle', 'rb') as handle:
    rec2_4b_29_1_cryolo_v1_filtered = pickle.load(handle)
with open(path4+'SSPicker_'+version+'_4b_'+lambda_4b+'_target_gen_prec2.pickle', 'rb') as handle:
    prec2_4b_29_1_cryolo_v1_filtered = pickle.load(handle)
with open(path4+'SSPicker_'+version+'_4b_'+lambda_4b+'_target_gen_fpr2.pickle', 'rb') as handle:
    fpr2_4b_29_1_cryolo_v1_filtered = pickle.load(handle)
with open(path4+'SSPicker_'+version+'_4b_'+lambda_4b+'_target_gen_rec3.pickle', 'rb') as handle:
    rec3_4b_29_1_cryolo_v1_filtered = pickle.load(handle)

lambda_4b = "220.0"
with open(path4+'SSPicker_'+version+'_4b_'+lambda_4b+'_target_gen_rec2.pickle', 'rb') as handle:
    rec2_4b_29_1_cryolo_v2 = pickle.load(handle)
with open(path4+'SSPicker_'+version+'_4b_'+lambda_4b+'_target_gen_prec2.pickle', 'rb') as handle:
    prec2_4b_29_1_cryolo_v2 = pickle.load(handle)
with open(path4+'SSPicker_'+version+'_4b_'+lambda_4b+'_target_gen_fpr2.pickle', 'rb') as handle:
    fpr2_4b_29_1_cryolo_v2 = pickle.load(handle)
with open(path4+'SSPicker_'+version+'_4b_'+lambda_4b+'_target_gen_rec3.pickle', 'rb') as handle:
    rec3_4b_29_1_cryolo_v2 = pickle.load(handle)
    
lambda_4b = "230.0"
with open(path4+'SSPicker_'+version+'_4b_'+lambda_4b+'_target_gen_rec2.pickle', 'rb') as handle:
    rec2_4b_29_1_cryolo_v2_filtered = pickle.load(handle)
with open(path4+'SSPicker_'+version+'_4b_'+lambda_4b+'_target_gen_prec2.pickle', 'rb') as handle:
    prec2_4b_29_1_cryolo_v2_filtered = pickle.load(handle)
with open(path4+'SSPicker_'+version+'_4b_'+lambda_4b+'_target_gen_fpr2.pickle', 'rb') as handle:
    fpr2_4b_29_1_cryolo_v2_filtered = pickle.load(handle)
with open(path4+'SSPicker_'+version+'_4b_'+lambda_4b+'_target_gen_rec3.pickle', 'rb') as handle:
    rec3_4b_29_1_cryolo_v2_filtered = pickle.load(handle)

# lambda_4b = "0"
# with open(path4+'SSPicker_'+version+'_4b_'+lambda_4b+'_target_gen_rec2.pickle', 'rb') as handle:
#     rec2_4b_29_1 = pickle.load(handle)
# with open(path4+'SSPicker_'+version+'_4b_'+lambda_4b+'_target_gen_prec2.pickle', 'rb') as handle:
#     prec2_4b_29_1 = pickle.load(handle)
# with open(path4+'SSPicker_'+version+'_4b_'+lambda_4b+'_target_gen_fpr2.pickle', 'rb') as handle:
#     fpr2_4b_29_1 = pickle.load(handle)
# with open(path4+'SSPicker_'+version+'_4b_'+lambda_4b+'_target_gen_rec3.pickle', 'rb') as handle:
#     rec3_4b_29_1 = pickle.load(handle)

lambda_4b = "1.1"
with open(path4+'SSPicker_'+version+'_4b_'+lambda_4b+'_target_gen_rec2.pickle', 'rb') as handle:
    rec2_4b_29_1 = pickle.load(handle)
with open(path4+'SSPicker_'+version+'_4b_'+lambda_4b+'_target_gen_prec2.pickle', 'rb') as handle:
    prec2_4b_29_1 = pickle.load(handle)
with open(path4+'SSPicker_'+version+'_4b_'+lambda_4b+'_target_gen_fpr2.pickle', 'rb') as handle:
    fpr2_4b_29_1 = pickle.load(handle)
with open(path4+'SSPicker_'+version+'_4b_'+lambda_4b+'_target_gen_rec3.pickle', 'rb') as handle:
    rec3_4b_29_1 = pickle.load(handle)
    
# version = "26_4"
# with open(path4+'SSPicker_'+version+'_2b_target_gen_rec2.pickle', 'rb') as handle:
#     rec2_2b_26_4 = pickle.load(handle)
# with open(path4+'SSPicker_'+version+'_2b_target_gen_prec2.pickle', 'rb') as handle:
#     prec2_2b_26_4 = pickle.load(handle)
# with open(path4+'SSPicker_'+version+'_2b_target_gen_fpr2.pickle', 'rb') as handle:
#     fpr2_2b_26_4 = pickle.load(handle)
# with open(path4+'SSPicker_'+version+'_2b_target_gen_rec3.pickle', 'rb') as handle:
#     rec3_2b_26_4 = pickle.load(handle)

version = "29_6"
lambda_4b = "1.1"
with open(path4+'SSPicker_'+version+'_4b_'+lambda_4b+'_target_gen_rec2.pickle', 'rb') as handle:
    rec2_4b_29_6 = pickle.load(handle)
with open(path4+'SSPicker_'+version+'_4b_'+lambda_4b+'_target_gen_prec2.pickle', 'rb') as handle:
    prec2_4b_29_6 = pickle.load(handle)
with open(path4+'SSPicker_'+version+'_4b_'+lambda_4b+'_target_gen_fpr2.pickle', 'rb') as handle:
    fpr2_4b_29_6 = pickle.load(handle)
with open(path4+'SSPicker_'+version+'_4b_'+lambda_4b+'_target_gen_rec3.pickle', 'rb') as handle:
    rec3_4b_29_6 = pickle.load(handle)


fig = p.figure()
ax = fig.gca()
ax.set_autoscale_on(False)
# ax.plot(rec2_5b_400, prec2_5b_400, label='crYOLO-old')
# ax.plot(rec2_4b_29_1_cryolo_v1, prec2_4b_29_1_cryolo_v1, label='crYOLO_v1')
ax.plot(rec2_4b_29_1_cryolo_v1_new, prec2_4b_29_1_cryolo_v1_new, label='crYOLO')
# ax.plot(rec2_5b_123, prec2_5b_123, label='crYOLO_123')
# ax.plot(rec2_4b_29_1_cryolo_v1_filtered, prec2_4b_29_1_cryolo_v1_filtered, label='crYOLO-v1_filtered')
# ax.plot(rec2_4b_29_1_cryolo_v2, prec2_4b_29_1_cryolo_v2, label='crYOLO-v2')
# ax.plot(rec2_4b_29_1_cryolo_v2_filtered, prec2_4b_29_1_cryolo_v2_filtered, label='crYOLO-v2_filtered')
# ax.plot(rec2_5b, prec2_5b, label='Boxnet-old')
# ax.plot(rec2_4b_29_1_boxnet_unmasked, prec2_4b_29_1_boxnet_unmasked, label='Boxnet_unmasked_old')
ax.plot(rec2_4b_29_1_boxnet_unmasked2, prec2_4b_29_1_boxnet_unmasked2, label='Boxnet')
# ax.plot(rec2_4b_29_1_boxnet_masked, prec2_4b_29_1_boxnet_masked, label='Boxnet_masked_provided')
ax.plot(rec2_4b_29_1_boxnet_masked2, prec2_4b_29_1_boxnet_masked2, label='Boxnet_masked')
# ax.plot(rec2_2b, prec2_2b, label='HydraPicker-old')
# ax.plot(rec2_5b_300_1, prec2_5b_300_1, label='7 models')
# ax.plot(rec2_4b_29_1, prec2_4b_29_1, label='HydraPicker_old')
ax.plot(rec2_4b_29_6, prec2_4b_29_6, label='HydraPicker')
# ax.plot(rec2_2b_26_4, prec2_2b_26_4, label='HydraPicker-light with resnet heads')
ax.axis([0,1,0,1])
ax.set(xlabel='Recall', ylabel='Precision')
ax.grid()
ax.legend()

fig = p.figure()
ax = fig.gca()
ax.set_autoscale_on(False)
# ax.plot(fpr2_5b_400, rec3_5b_400, label='crYOLO-old')
# ax.plot(fpr2_4b_29_1_cryolo_v1, rec3_4b_29_1_cryolo_v1, label='crYOLO_v1')
ax.plot(fpr2_4b_29_1_cryolo_v1_new, rec3_4b_29_1_cryolo_v1_new, label='crYOLO')
# ax.plot(fpr2_5b_123, rec3_5b_123, label='crYOLO-123')
# ax.plot(fpr2_4b_29_1_cryolo_v1_filtered, rec3_4b_29_1_cryolo_v1_filtered, label='crYOLO-v1_filtered')
# ax.plot(fpr2_4b_29_1_cryolo_v2, rec3_4b_29_1_cryolo_v2, label='crYOLO-v2')
# ax.plot(fpr2_4b_29_1_cryolo_v2_filtered, rec3_4b_29_1_cryolo_v2_filtered, label='crYOLO-v2_filtered')
# ax.plot(fpr2_5b, rec3_5b, label='Boxnet-old')
# ax.plot(fpr2_4b_29_1_boxnet_unmasked, rec3_4b_29_1_boxnet_unmasked, label='Boxnet_unmasked_old')
ax.plot(fpr2_4b_29_1_boxnet_unmasked2, rec3_4b_29_1_boxnet_unmasked2, label='Boxnet')
# ax.plot(fpr2_4b_29_1_boxnet_masked, rec3_4b_29_1_boxnet_masked, label='Boxnet_masked_provided')
ax.plot(fpr2_4b_29_1_boxnet_masked2, rec3_4b_29_1_boxnet_masked2, label='Boxnet_masked')
# ax.plot(fpr2_2b, rec3_2b, label='HydraPicker-old')
# ax.plot(fpr2_5b_300_1, rec3_5b_300_1, label='7 models')
# ax.plot(fpr2_4b_29_1, rec3_4b_29_1, label='HydraPicker_old')
ax.plot(fpr2_4b_29_6, rec3_4b_29_6, label='HydraPicker')
# ax.plot(fpr2_2b_26_4, rec3_2b_26_4, label='HydraPicker-light with resnet heads')
ax.axis([0,1,0,1])
ax.set(xlabel='False-Positive Rate', ylabel='Recall')
ax.grid()
ax.legend()

# %%
print("Targets")
version = "23"

lambda_5b = "400.0"
with open(path4+'SSPicker_'+version+'_5b_'+lambda_5b+'_target_gen_auc.pickle', 'rb') as handle:
    auc = pickle.load(handle)
with open(path4+'SSPicker_'+version+'_5b_'+lambda_5b+'_target_gen_prec_at_rec90.pickle', 'rb') as handle:
    prec_at_rec90 = pickle.load(handle)
with open(path4+'SSPicker_'+version+'_5b_'+lambda_5b+'_target_gen_rec_at_prec90.pickle', 'rb') as handle:
    rec_at_prec90 = pickle.load(handle)
with open(path4+'SSPicker_'+version+'_5b_'+lambda_5b+'_target_gen_auroc.pickle', 'rb') as handle:
    auroc = pickle.load(handle)

print('crYOLO-old')
print("AP:                          ", auc)
print("Precision at recall=90:      ", prec_at_rec90)
print("Recall at precision=90:      ", rec_at_prec90)
print("AROC:                        ", auroc)
print("\n")

version = "29_1"
lambda_4b = "200.0"
with open(path4+'SSPicker_'+version+'_4b_'+lambda_4b+'_target_gen_auc.pickle', 'rb') as handle:
    auc = pickle.load(handle)
with open(path4+'SSPicker_'+version+'_4b_'+lambda_4b+'_target_gen_prec_at_rec90.pickle', 'rb') as handle:
    prec_at_rec90 = pickle.load(handle)
with open(path4+'SSPicker_'+version+'_4b_'+lambda_4b+'_target_gen_rec_at_prec90.pickle', 'rb') as handle:
    rec_at_prec90 = pickle.load(handle)
with open(path4+'SSPicker_'+version+'_4b_'+lambda_4b+'_target_gen_auroc.pickle', 'rb') as handle:
    auroc = pickle.load(handle)

print('crYOLO-v1')
print("AP:                          ", auc)
print("Precision at recall=90:      ", prec_at_rec90)
print("Recall at precision=90:      ", rec_at_prec90)
print("AROC:                        ", auroc)
print("\n")

lambda_4b = "210.0"
with open(path4+'SSPicker_'+version+'_4b_'+lambda_4b+'_target_gen_auc.pickle', 'rb') as handle:
    auc = pickle.load(handle)
with open(path4+'SSPicker_'+version+'_4b_'+lambda_4b+'_target_gen_prec_at_rec90.pickle', 'rb') as handle:
    prec_at_rec90 = pickle.load(handle)
with open(path4+'SSPicker_'+version+'_4b_'+lambda_4b+'_target_gen_rec_at_prec90.pickle', 'rb') as handle:
    rec_at_prec90 = pickle.load(handle)
with open(path4+'SSPicker_'+version+'_4b_'+lambda_4b+'_target_gen_auroc.pickle', 'rb') as handle:
    auroc = pickle.load(handle)

print('crYOLO-v1-filtered')
print("AP:                          ", auc)
print("Precision at recall=90:      ", prec_at_rec90)
print("Recall at precision=90:      ", rec_at_prec90)
print("AROC:                        ", auroc)
print("\n")

lambda_4b = "220.0"
with open(path4+'SSPicker_'+version+'_4b_'+lambda_4b+'_target_gen_auc.pickle', 'rb') as handle:
    auc = pickle.load(handle)
with open(path4+'SSPicker_'+version+'_4b_'+lambda_4b+'_target_gen_prec_at_rec90.pickle', 'rb') as handle:
    prec_at_rec90 = pickle.load(handle)
with open(path4+'SSPicker_'+version+'_4b_'+lambda_4b+'_target_gen_rec_at_prec90.pickle', 'rb') as handle:
    rec_at_prec90 = pickle.load(handle)
with open(path4+'SSPicker_'+version+'_4b_'+lambda_4b+'_target_gen_auroc.pickle', 'rb') as handle:
    auroc = pickle.load(handle)

print('crYOLO-v2')
print("AP:                          ", auc)
print("Precision at recall=90:      ", prec_at_rec90)
print("Recall at precision=90:      ", rec_at_prec90)
print("AROC:                        ", auroc)
print("\n")

lambda_4b = "230.0"
with open(path4+'SSPicker_'+version+'_4b_'+lambda_4b+'_target_gen_auc.pickle', 'rb') as handle:
    auc = pickle.load(handle)
with open(path4+'SSPicker_'+version+'_4b_'+lambda_4b+'_target_gen_prec_at_rec90.pickle', 'rb') as handle:
    prec_at_rec90 = pickle.load(handle)
with open(path4+'SSPicker_'+version+'_4b_'+lambda_4b+'_target_gen_rec_at_prec90.pickle', 'rb') as handle:
    rec_at_prec90 = pickle.load(handle)
with open(path4+'SSPicker_'+version+'_4b_'+lambda_4b+'_target_gen_auroc.pickle', 'rb') as handle:
    auroc = pickle.load(handle)

print('crYOLO-v2-filtered')
print("AP:                          ", auc)
print("Precision at recall=90:      ", prec_at_rec90)
print("Recall at precision=90:      ", rec_at_prec90)
print("AROC:                        ", auroc)
print("\n")

version = "23"
lambda_5b = "201.0"
with open(path4+'SSPicker_'+version+'_5b_'+lambda_5b+'_target_gen_auc.pickle', 'rb') as handle:
    auc = pickle.load(handle)
with open(path4+'SSPicker_'+version+'_5b_'+lambda_5b+'_target_gen_prec_at_rec90.pickle', 'rb') as handle:
    prec_at_rec90 = pickle.load(handle)
with open(path4+'SSPicker_'+version+'_5b_'+lambda_5b+'_target_gen_rec_at_prec90.pickle', 'rb') as handle:
    rec_at_prec90 = pickle.load(handle)
with open(path4+'SSPicker_'+version+'_5b_'+lambda_5b+'_target_gen_auroc.pickle', 'rb') as handle:
    auroc = pickle.load(handle)

print('Boxnet-old')
print("AP:                          ", auc)
print("Precision at recall=90:      ", prec_at_rec90)
print("Recall at precision=90:      ", rec_at_prec90)
print("AROC:                        ", auroc)
print("\n")


version = "29_1"
lambda_4b = "100.0"
with open(path4+'SSPicker_'+version+'_4b_'+lambda_4b+'_target_gen_auc.pickle', 'rb') as handle:
    auc = pickle.load(handle)
with open(path4+'SSPicker_'+version+'_4b_'+lambda_4b+'_target_gen_prec_at_rec90.pickle', 'rb') as handle:
    prec_at_rec90 = pickle.load(handle)
with open(path4+'SSPicker_'+version+'_4b_'+lambda_4b+'_target_gen_rec_at_prec90.pickle', 'rb') as handle:
    rec_at_prec90 = pickle.load(handle)
with open(path4+'SSPicker_'+version+'_4b_'+lambda_4b+'_target_gen_auroc.pickle', 'rb') as handle:
    auroc = pickle.load(handle)

print('Boxnet-unmasked')
print("AP:                          ", auc)
print("Precision at recall=90:      ", prec_at_rec90)
print("Recall at precision=90:      ", rec_at_prec90)
print("AROC:                        ", auroc)
print("\n")

lambda_4b = "120.0"
with open(path4+'SSPicker_'+version+'_4b_'+lambda_4b+'_target_gen_auc.pickle', 'rb') as handle:
    auc = pickle.load(handle)
with open(path4+'SSPicker_'+version+'_4b_'+lambda_4b+'_target_gen_prec_at_rec90.pickle', 'rb') as handle:
    prec_at_rec90 = pickle.load(handle)
with open(path4+'SSPicker_'+version+'_4b_'+lambda_4b+'_target_gen_rec_at_prec90.pickle', 'rb') as handle:
    rec_at_prec90 = pickle.load(handle)
with open(path4+'SSPicker_'+version+'_4b_'+lambda_4b+'_target_gen_auroc.pickle', 'rb') as handle:
    auroc = pickle.load(handle)

print('Boxnet-masked')
print("AP:                          ", auc)
print("Precision at recall=90:      ", prec_at_rec90)
print("Recall at precision=90:      ", rec_at_prec90)
print("AROC:                        ", auroc)
print("\n")

version = "23"
with open(path4+'SSPicker_'+version+'_2b_target_gen_auc.pickle', 'rb') as handle:
    auc = pickle.load(handle)
with open(path4+'SSPicker_'+version+'_2b_target_gen_prec_at_rec90.pickle', 'rb') as handle:
    prec_at_rec90 = pickle.load(handle)
with open(path4+'SSPicker_'+version+'_2b_target_gen_rec_at_prec90.pickle', 'rb') as handle:
    rec_at_prec90 = pickle.load(handle)
with open(path4+'SSPicker_'+version+'_2b_target_gen_auroc.pickle', 'rb') as handle:
    auroc = pickle.load(handle)


print('HydraPicker-old')
print("AP:                          ", auc)
print("Precision at recall=90:      ", prec_at_rec90)
print("Recall at precision=90:      ", rec_at_prec90)
print("AROC:                        ", auroc)
print("\n")



version = "29_1"
lambda_4b = "1.1"
with open(path4+'SSPicker_'+version+'_4b_'+lambda_4b+'_target_gen_auc.pickle', 'rb') as handle:
    auc = pickle.load(handle)
with open(path4+'SSPicker_'+version+'_4b_'+lambda_4b+'_target_gen_prec_at_rec90.pickle', 'rb') as handle:
    prec_at_rec90 = pickle.load(handle)
with open(path4+'SSPicker_'+version+'_4b_'+lambda_4b+'_target_gen_rec_at_prec90.pickle', 'rb') as handle:
    rec_at_prec90 = pickle.load(handle)
with open(path4+'SSPicker_'+version+'_4b_'+lambda_4b+'_target_gen_auroc.pickle', 'rb') as handle:
    auroc = pickle.load(handle)

print('HydraPicker-new')
print("AP:                          ", auc)
print("Precision at recall=90:      ", prec_at_rec90)
print("Recall at precision=90:      ", rec_at_prec90)
print("AROC:                        ", auroc)
print("\n")

# version = "26_4"

# with open(path4+'SSPicker_'+version+'_2b_target_gen_auc.pickle', 'rb') as handle:
#     auc = pickle.load(handle)
# with open(path4+'SSPicker_'+version+'_2b_target_gen_prec_at_rec90.pickle', 'rb') as handle:
#     prec_at_rec90 = pickle.load(handle)
# with open(path4+'SSPicker_'+version+'_2b_target_gen_rec_at_prec90.pickle', 'rb') as handle:
#     rec_at_prec90 = pickle.load(handle)
# with open(path4+'SSPicker_'+version+'_2b_target_gen_auroc.pickle', 'rb') as handle:
#     auroc = pickle.load(handle)

# print('HydraPicker-light with resnet heads')
# print("AP:                          ", auc)
# print("Precision at recall=90:      ", prec_at_rec90)
# print("Recall at precision=90:      ", rec_at_prec90)
# print("AROC:                        ", auroc)
# print("\n")
# Out:
# Targets
# crYOLO-old
# AP:                           0.49641052578927997
# Precision at recall=90:       0.0
# Recall at precision=90:       0.059490084985835696
# AROC:                         0.6344301952211822
#
#
# crYOLO-v1
# AP:                           0.6178577566340063
# Precision at recall=90:       0.0
# Recall at precision=90:       0.3073654390934844
# AROC:                         0.7159471850452257
#
#
# crYOLO-v1-filtered
# AP:                           0.431643061447399
# Precision at recall=90:       0.0
# Recall at precision=90:       0.04036827195467421
# AROC:                         0.5922020411002444
#
#
# crYOLO-v2
# AP:                           0.2740956502368357
# Precision at recall=90:       0.0
# Recall at precision=90:       0
# AROC:                         0.5518672974590926
#
#
# crYOLO-v2-filtered
# AP:                           0.23791078284258524
# Precision at recall=90:       0.0
# Recall at precision=90:       0
# AROC:                         0.563828420672549
#
#
# Boxnet-old
# AP:                           0.5828087780578143
# Precision at recall=90:       0.0
# Recall at precision=90:       0.029745042492917848
# AROC:                         0.809453475878713
#
#
# Boxnet-unmasked
# AP:                           0.6106294709605727
# Precision at recall=90:       0.0
# Recall at precision=90:       0.03824362606232295
# AROC:                         0.7968955731556476
#
#
# Boxnet-masked
# AP:                           0.5273004793168875
# Precision at recall=90:       0.0
# Recall at precision=90:       0.007082152974504249
# AROC:                         0.6618961832036926
#
#
# HydraPicker-old
# AP:                           0.7145314417992912
# Precision at recall=90:       0.34277238403452
# Recall at precision=90:       0.11012747875354108
# AROC:                         0.912923044648734
#
#
# HydraPicker-new
# AP:                           0.796147612421127
# Precision at recall=90:       0.6322395967988776
# Recall at precision=90:       0.2475212464589235
# AROC:                         0.9480926198540021

# %%
# version = "23"
# # lambda_4a = "0.001"
# # lambda_5a = "0.001"
# lambda_4b = "3e-05"
# lambda_5b = "101.0"
# # lambda_5b = "200.0"
# lambda_4c = "3e-05"
# lambda_5c = "201.0"

# with open(path4+'SSPicker_'+version+'_5b_'+lambda_5b+'_target_gen_auc.pickle', 'rb') as handle:
#     auc = pickle.load(handle)
# with open(path4+'SSPicker_'+version+'_5b_'+lambda_5b+'_target_gen_prec_at_rec90.pickle', 'rb') as handle:
#     prec_at_rec90 = pickle.load(handle)
# with open(path4+'SSPicker_'+version+'_5b_'+lambda_5b+'_target_gen_rec_at_prec90.pickle', 'rb') as handle:
#     rec_at_prec90 = pickle.load(handle)
# with open(path4+'SSPicker_'+version+'_5b_'+lambda_5b+'_target_gen_auroc.pickle', 'rb') as handle:
#     auroc = pickle.load(handle)

# print('HydraPicker: Tested with generic head')
# print("AP:                          ", auc)
# print("Precision at recall=90:      ", prec_at_rec90)
# print("Recall at precision=90:      ", rec_at_prec90)
# print("AROC:                        ", auroc)

# print("\n")

# %%
version = "23"
# lambda_4a = "0.001"
# lambda_5a = "0.001"
lambda_4b = "100.0"
lambda_5b = "200.0"
lambda_4c = "3e-05"
lambda_5c = "201.0"

# %% [markdown]
# # Fine-Tuned

# %%
with open(path4+'SSPicker_'+version+'_4c_'+lambda_4c+'_target_spec_rec2.pickle', 'rb') as handle:
    rec2_4c = pickle.load(handle)
with open(path4+'SSPicker_'+version+'_4c_'+lambda_4c+'_target_spec_prec2.pickle', 'rb') as handle:
    prec2_4c = pickle.load(handle)
with open(path4+'SSPicker_'+version+'_4c_'+lambda_4c+'_target_spec_fpr2.pickle', 'rb') as handle:
    fpr2_4c = pickle.load(handle)
with open(path4+'SSPicker_'+version+'_4c_'+lambda_4c+'_target_spec_rec3.pickle', 'rb') as handle:
    rec3_4c = pickle.load(handle)

lambda_5b = "300.0"
with open(path4+'SSPicker_'+version+'_5b_'+lambda_5b+'_target_gen_rec2.pickle', 'rb') as handle:
    rec2_5b_300 = pickle.load(handle)
with open(path4+'SSPicker_'+version+'_5b_'+lambda_5b+'_target_gen_prec2.pickle', 'rb') as handle:
    prec2_5b_300 = pickle.load(handle)
with open(path4+'SSPicker_'+version+'_5b_'+lambda_5b+'_target_gen_fpr2.pickle', 'rb') as handle:
    fpr2_5b_300 = pickle.load(handle)
with open(path4+'SSPicker_'+version+'_5b_'+lambda_5b+'_target_gen_rec3.pickle', 'rb') as handle:
    rec3_5b_300 = pickle.load(handle)

    
lambda_5b = "202.0"
with open(path4+'SSPicker_'+version+'_5b_'+lambda_5b+'_target_gen_rec2.pickle', 'rb') as handle:
    rec2_5b_200 = pickle.load(handle)
with open(path4+'SSPicker_'+version+'_5b_'+lambda_5b+'_target_gen_prec2.pickle', 'rb') as handle:
    prec2_5b_200 = pickle.load(handle)
with open(path4+'SSPicker_'+version+'_5b_'+lambda_5b+'_target_gen_fpr2.pickle', 'rb') as handle:
    fpr2_5b_200 = pickle.load(handle)
with open(path4+'SSPicker_'+version+'_5b_'+lambda_5b+'_target_gen_rec3.pickle', 'rb') as handle:
    rec3_5b_200 = pickle.load(handle)
# with open(path4+'SSPicker_'+version+'_5b_'+lambda_5b+'_target_gen_avgs2.pickle', 'rb') as handle:
#     avgs2_5b = pickle.load(handle)

lambda_5b = "401.0"
with open(path4+'SSPicker_'+version+'_5b_'+lambda_5b+'_target_gen_rec2.pickle', 'rb') as handle:
    rec2_5b_401 = pickle.load(handle)
with open(path4+'SSPicker_'+version+'_5b_'+lambda_5b+'_target_gen_prec2.pickle', 'rb') as handle:
    prec2_5b_401 = pickle.load(handle)
with open(path4+'SSPicker_'+version+'_5b_'+lambda_5b+'_target_gen_fpr2.pickle', 'rb') as handle:
    fpr2_5b_401 = pickle.load(handle)
with open(path4+'SSPicker_'+version+'_5b_'+lambda_5b+'_target_gen_rec3.pickle', 'rb') as handle:
    rec3_5b_401 = pickle.load(handle)
    
version = "29_1"

lambda_5b = "300.1"
with open(path4+'SSPicker_'+version+'_5b_'+lambda_5b+'_target_gen_rec2.pickle', 'rb') as handle:
    rec2_5b_300_1 = pickle.load(handle)
with open(path4+'SSPicker_'+version+'_5b_'+lambda_5b+'_target_gen_prec2.pickle', 'rb') as handle:
    prec2_5b_300_1 = pickle.load(handle)
with open(path4+'SSPicker_'+version+'_5b_'+lambda_5b+'_target_gen_fpr2.pickle', 'rb') as handle:
    fpr2_5b_300_1 = pickle.load(handle)
with open(path4+'SSPicker_'+version+'_5b_'+lambda_5b+'_target_gen_rec3.pickle', 'rb') as handle:
    rec3_5b_300_1 = pickle.load(handle)

lambda_4b = "240.1"
with open(path4+'SSPicker_'+version+'_4b_'+lambda_4b+'_target_gen_rec2.pickle', 'rb') as handle:
    rec2_4c_29_1_cryolo_v1 = pickle.load(handle)
with open(path4+'SSPicker_'+version+'_4b_'+lambda_4b+'_target_gen_prec2.pickle', 'rb') as handle:
    prec2_4c_29_1_cryolo_v1 = pickle.load(handle)
with open(path4+'SSPicker_'+version+'_4b_'+lambda_4b+'_target_gen_fpr2.pickle', 'rb') as handle:
    fpr2_4c_29_1_cryolo_v1 = pickle.load(handle)
with open(path4+'SSPicker_'+version+'_4b_'+lambda_4b+'_target_gen_rec3.pickle', 'rb') as handle:
    rec3_4c_29_1_cryolo_v1 = pickle.load(handle)

lambda_4b = "240.2"
with open(path4+'SSPicker_'+version+'_4b_'+lambda_4b+'_target_gen_rec2.pickle', 'rb') as handle:
    rec2_4c_29_1_cryolo_v1_new = pickle.load(handle)
with open(path4+'SSPicker_'+version+'_4b_'+lambda_4b+'_target_gen_prec2.pickle', 'rb') as handle:
    prec2_4c_29_1_cryolo_v1_new = pickle.load(handle)
with open(path4+'SSPicker_'+version+'_4b_'+lambda_4b+'_target_gen_fpr2.pickle', 'rb') as handle:
    fpr2_4c_29_1_cryolo_v1_new = pickle.load(handle)
with open(path4+'SSPicker_'+version+'_4b_'+lambda_4b+'_target_gen_rec3.pickle', 'rb') as handle:
    rec3_4c_29_1_cryolo_v1_new = pickle.load(handle)
    
lambda_4b = "250.0"
with open(path4+'SSPicker_'+version+'_4b_'+lambda_4b+'_target_gen_rec2.pickle', 'rb') as handle:
    rec2_4c_29_1_cryolo_v1_filtered = pickle.load(handle)
with open(path4+'SSPicker_'+version+'_4b_'+lambda_4b+'_target_gen_prec2.pickle', 'rb') as handle:
    prec2_4c_29_1_cryolo_v1_filtered = pickle.load(handle)
with open(path4+'SSPicker_'+version+'_4b_'+lambda_4b+'_target_gen_fpr2.pickle', 'rb') as handle:
    fpr2_4c_29_1_cryolo_v1_filtered = pickle.load(handle)
with open(path4+'SSPicker_'+version+'_4b_'+lambda_4b+'_target_gen_rec3.pickle', 'rb') as handle:
    rec3_4c_29_1_cryolo_v1_filtered = pickle.load(handle)

lambda_4b = "260.0"
with open(path4+'SSPicker_'+version+'_4b_'+lambda_4b+'_target_gen_rec2.pickle', 'rb') as handle:
    rec2_4c_29_1_cryolo_v2 = pickle.load(handle)
with open(path4+'SSPicker_'+version+'_4b_'+lambda_4b+'_target_gen_prec2.pickle', 'rb') as handle:
    prec2_4c_29_1_cryolo_v2 = pickle.load(handle)
with open(path4+'SSPicker_'+version+'_4b_'+lambda_4b+'_target_gen_fpr2.pickle', 'rb') as handle:
    fpr2_4c_29_1_cryolo_v2 = pickle.load(handle)
with open(path4+'SSPicker_'+version+'_4b_'+lambda_4b+'_target_gen_rec3.pickle', 'rb') as handle:
    rec3_4c_29_1_cryolo_v2 = pickle.load(handle)

lambda_4b = "270.0"
with open(path4+'SSPicker_'+version+'_4b_'+lambda_4b+'_target_gen_rec2.pickle', 'rb') as handle:
    rec2_4c_29_1_cryolo_v2_filtered = pickle.load(handle)
with open(path4+'SSPicker_'+version+'_4b_'+lambda_4b+'_target_gen_prec2.pickle', 'rb') as handle:
    prec2_4c_29_1_cryolo_v2_filtered = pickle.load(handle)
with open(path4+'SSPicker_'+version+'_4b_'+lambda_4b+'_target_gen_fpr2.pickle', 'rb') as handle:
    fpr2_4c_29_1_cryolo_v2_filtered = pickle.load(handle)
with open(path4+'SSPicker_'+version+'_4b_'+lambda_4b+'_target_gen_rec3.pickle', 'rb') as handle:
    rec3_4c_29_1_cryolo_v2_filtered = pickle.load(handle)

lambda_4b = "101.0"
with open(path4+'SSPicker_'+version+'_4b_'+lambda_4b+'_target_gen_rec2.pickle', 'rb') as handle:
    rec2_4c_29_1_boxnet_unmasked = pickle.load(handle)
with open(path4+'SSPicker_'+version+'_4b_'+lambda_4b+'_target_gen_prec2.pickle', 'rb') as handle:
    prec2_4c_29_1_boxnet_unmasked = pickle.load(handle)
with open(path4+'SSPicker_'+version+'_4b_'+lambda_4b+'_target_gen_fpr2.pickle', 'rb') as handle:
    fpr2_4c_29_1_boxnet_unmasked = pickle.load(handle)
with open(path4+'SSPicker_'+version+'_4b_'+lambda_4b+'_target_gen_rec3.pickle', 'rb') as handle:
    rec3_4c_29_1_boxnet_unmasked = pickle.load(handle)
    
lambda_4b = "101.1"
with open(path4+'SSPicker_'+version+'_4b_'+lambda_4b+'_target_gen_rec2.pickle', 'rb') as handle:
    rec2_4c_29_1_boxnet_unmasked2 = pickle.load(handle)
with open(path4+'SSPicker_'+version+'_4b_'+lambda_4b+'_target_gen_prec2.pickle', 'rb') as handle:
    prec2_4c_29_1_boxnet_unmasked2 = pickle.load(handle)
with open(path4+'SSPicker_'+version+'_4b_'+lambda_4b+'_target_gen_fpr2.pickle', 'rb') as handle:
    fpr2_4c_29_1_boxnet_unmasked2 = pickle.load(handle)
with open(path4+'SSPicker_'+version+'_4b_'+lambda_4b+'_target_gen_rec3.pickle', 'rb') as handle:
    rec3_4c_29_1_boxnet_unmasked2 = pickle.load(handle)
    
lambda_4b = "103.0"
with open(path4+'SSPicker_'+version+'_4b_'+lambda_4b+'_target_gen_rec2.pickle', 'rb') as handle:
    rec2_4c_29_1_boxnet_masked2 = pickle.load(handle)
with open(path4+'SSPicker_'+version+'_4b_'+lambda_4b+'_target_gen_prec2.pickle', 'rb') as handle:
    prec2_4c_29_1_boxnet_masked2 = pickle.load(handle)
with open(path4+'SSPicker_'+version+'_4b_'+lambda_4b+'_target_gen_fpr2.pickle', 'rb') as handle:
    fpr2_4c_29_1_boxnet_masked2 = pickle.load(handle)
with open(path4+'SSPicker_'+version+'_4b_'+lambda_4b+'_target_gen_rec3.pickle', 'rb') as handle:
    rec3_4c_29_1_boxnet_masked2 = pickle.load(handle)

lambda_4c = "0"
with open(path4+'SSPicker_'+version+'_4c_'+lambda_4c+'_target_spec_rec2.pickle', 'rb') as handle:
    rec2_4c_29_1 = pickle.load(handle)
with open(path4+'SSPicker_'+version+'_4c_'+lambda_4c+'_target_spec_prec2.pickle', 'rb') as handle:
    prec2_4c_29_1 = pickle.load(handle)
with open(path4+'SSPicker_'+version+'_4c_'+lambda_4c+'_target_spec_fpr2.pickle', 'rb') as handle:
    fpr2_4c_29_1 = pickle.load(handle)
with open(path4+'SSPicker_'+version+'_4c_'+lambda_4c+'_target_spec_rec3.pickle', 'rb') as handle:
    rec3_4c_29_1 = pickle.load(handle)

version = "29_6"
lambda_4c = "0.0"
with open(path4+'SSPicker_'+version+'_4c_'+lambda_4c+'_target_spec_rec2.pickle', 'rb') as handle:
    rec2_4c_29_6 = pickle.load(handle)
with open(path4+'SSPicker_'+version+'_4c_'+lambda_4c+'_target_spec_prec2.pickle', 'rb') as handle:
    prec2_4c_29_6 = pickle.load(handle)
with open(path4+'SSPicker_'+version+'_4c_'+lambda_4c+'_target_spec_fpr2.pickle', 'rb') as handle:
    fpr2_4c_29_6 = pickle.load(handle)
with open(path4+'SSPicker_'+version+'_4c_'+lambda_4c+'_target_spec_rec3.pickle', 'rb') as handle:
    rec3_4c_29_6 = pickle.load(handle)
    
lambda_4c = "0.1"
with open(path4+'SSPicker_'+version+'_4c_'+lambda_4c+'_target_spec_rec2.pickle', 'rb') as handle:
    rec2_4c_29_6_new = pickle.load(handle)
with open(path4+'SSPicker_'+version+'_4c_'+lambda_4c+'_target_spec_prec2.pickle', 'rb') as handle:
    prec2_4c_29_6_new = pickle.load(handle)
with open(path4+'SSPicker_'+version+'_4c_'+lambda_4c+'_target_spec_fpr2.pickle', 'rb') as handle:
    fpr2_4c_29_6_new = pickle.load(handle)
with open(path4+'SSPicker_'+version+'_4c_'+lambda_4c+'_target_spec_rec3.pickle', 'rb') as handle:
    rec3_4c_29_6_new = pickle.load(handle)

fig = p.figure()
ax = fig.gca()
ax.set_autoscale_on(False)
# ax.plot(rec2_5b_401, prec2_5b_401, label='crYOLO-old')
# ax.plot(rec2_4c_29_1_cryolo_v1, prec2_4c_29_1_cryolo_v1, label='crYOLO_v1')
ax.plot(rec2_4c_29_1_cryolo_v1_new, prec2_4c_29_1_cryolo_v1_new, label='crYOLO')
# ax.plot(rec2_4c_29_1_cryolo_v1_filtered, prec2_4c_29_1_cryolo_v1_filtered, label='crYOLO-v1_filtered')
# ax.plot(rec2_4c_29_1_cryolo_v2, prec2_4c_29_1_cryolo_v2, label='crYOLO-v2')
# ax.plot(rec2_4c_29_1_cryolo_v2_filtered, prec2_4c_29_1_cryolo_v2_filtered, label='crYOLO-v2_filtered')
# ax.plot(rec2_5b_200, prec2_5b_200, label='Boxnet-old')
# ax.plot(rec2_4c_29_1_boxnet_unmasked, prec2_4c_29_1_boxnet_unmasked, label='Boxnet_unmasked_old')
ax.plot(rec2_4c_29_1_boxnet_unmasked2, prec2_4c_29_1_boxnet_unmasked2, label='Boxnet')
ax.plot(rec2_4c_29_1_boxnet_masked2, prec2_4c_29_1_boxnet_masked2, label='Boxnet_masked')
# ax.plot(rec2_5b_300, prec2_5b_300, label='7 models')
# ax.plot(rec2_5b_300_1, prec2_5b_300_1, label='7 models')
# ax.plot(rec2_4c, prec2_4c, label='HydraPicker-old')
# ax.plot(rec2_4c_29_1, prec2_4c_29_1, label='HydraPicker_old')
# ax.plot(rec2_4c_29_6, prec2_4c_29_6, label='HydraPicker_old')
ax.plot(rec2_4c_29_6_new, prec2_4c_29_6_new, label='HydraPicker')
ax.axis([0,1,0,1])
ax.set(xlabel='Recall', ylabel='Precision')
ax.grid()
ax.legend()

fig = p.figure()
ax = fig.gca()
ax.set_autoscale_on(False)
# ax.plot(fpr2_5b_401, rec3_5b_401, label='crYOLO-old')
# ax.plot(fpr2_4c_29_1_cryolo_v1, rec3_4c_29_1_cryolo_v1, label='crYOLO_v1')
ax.plot(fpr2_4c_29_1_cryolo_v1_new, rec3_4c_29_1_cryolo_v1_new, label='crYOLO')
# ax.plot(fpr2_4c_29_1_cryolo_v1_filtered, rec3_4c_29_1_cryolo_v1_filtered, label='crYOLO-v1_filtered')
# ax.plot(fpr2_4c_29_1_cryolo_v2, rec3_4c_29_1_cryolo_v2, label='crYOLO-v2')
# ax.plot(fpr2_4c_29_1_cryolo_v2_filtered, rec3_4c_29_1_cryolo_v2_filtered, label='crYOLO-v2_filtered')
# ax.plot(fpr2_5b_200, rec3_5b_200, label='Boxnet-old')
# ax.plot(fpr2_4c_29_1_boxnet_unmasked, rec3_4c_29_1_boxnet_unmasked, label='Boxnet_unmasked_old')
ax.plot(fpr2_4c_29_1_boxnet_unmasked2, rec3_4c_29_1_boxnet_unmasked2, label='Boxnet')
ax.plot(fpr2_4c_29_1_boxnet_masked2, rec3_4c_29_1_boxnet_masked2, label='Boxnet_masked')
# ax.plot(fpr2_5b_300, rec3_5b_300, label='7 models')
# ax.plot(fpr2_5b_300_1, rec3_5b_300_1, label='7 models')
# ax.plot(fpr2_4c, rec3_4c, label='HydraPicker-old')
# ax.plot(fpr2_4c_29_1, rec3_4c_29_1, label='HydraPicker_old')
# ax.plot(fpr2_4c_29_6, rec3_4c_29_6, label='HydraPicker_old')
ax.plot(fpr2_4c_29_6_new, rec3_4c_29_6_new, label='HydraPicker')
ax.axis([0,1,0,1])
ax.set(xlabel='False-Positive Rate', ylabel='Recall')
ax.grid()
ax.legend()

# %%
version = "23"
# lambda_4a = "0.001"
# lambda_5a = "0.001"
lambda_4b = "100.0"
lambda_5b = "200.0"
lambda_4c = "3e-05"
lambda_5c = "201.0"

lambda_5b = "401.0"
with open(path4+'SSPicker_'+version+'_5b_'+lambda_5b+'_target_gen_auc.pickle', 'rb') as handle:
    auc = pickle.load(handle)
with open(path4+'SSPicker_'+version+'_5b_'+lambda_5b+'_target_gen_prec_at_rec90.pickle', 'rb') as handle:
    prec_at_rec90 = pickle.load(handle)
with open(path4+'SSPicker_'+version+'_5b_'+lambda_5b+'_target_gen_rec_at_prec90.pickle', 'rb') as handle:
    rec_at_prec90 = pickle.load(handle)
with open(path4+'SSPicker_'+version+'_5b_'+lambda_5b+'_target_gen_auroc.pickle', 'rb') as handle:
    auroc = pickle.load(handle)

print('crYOLO-old')
print("AP:                          ", auc)
print("Precision at recall=90:      ", prec_at_rec90)
print("Recall at precision=90:      ", rec_at_prec90)
print("AROC:                        ", auroc)

print("\n")

version = "29_1"
lambda_4b = "240.1"
with open(path4+'SSPicker_'+version+'_4b_'+lambda_4b+'_target_gen_auc.pickle', 'rb') as handle:
    auc = pickle.load(handle)
with open(path4+'SSPicker_'+version+'_4b_'+lambda_4b+'_target_gen_prec_at_rec90.pickle', 'rb') as handle:
    prec_at_rec90 = pickle.load(handle)
with open(path4+'SSPicker_'+version+'_4b_'+lambda_4b+'_target_gen_rec_at_prec90.pickle', 'rb') as handle:
    rec_at_prec90 = pickle.load(handle)
with open(path4+'SSPicker_'+version+'_4b_'+lambda_4b+'_target_gen_auroc.pickle', 'rb') as handle:
    auroc = pickle.load(handle)

print('crYOLO-v1')
print("AP:                          ", auc)
print("Precision at recall=90:      ", prec_at_rec90)
print("Recall at precision=90:      ", rec_at_prec90)
print("AROC:                        ", auroc)
print("\n")

lambda_4b = "250.0"
with open(path4+'SSPicker_'+version+'_4b_'+lambda_4b+'_target_gen_auc.pickle', 'rb') as handle:
    auc = pickle.load(handle)
with open(path4+'SSPicker_'+version+'_4b_'+lambda_4b+'_target_gen_prec_at_rec90.pickle', 'rb') as handle:
    prec_at_rec90 = pickle.load(handle)
with open(path4+'SSPicker_'+version+'_4b_'+lambda_4b+'_target_gen_rec_at_prec90.pickle', 'rb') as handle:
    rec_at_prec90 = pickle.load(handle)
with open(path4+'SSPicker_'+version+'_4b_'+lambda_4b+'_target_gen_auroc.pickle', 'rb') as handle:
    auroc = pickle.load(handle)

print('crYOLO-v1_filtered')
print("AP:                          ", auc)
print("Precision at recall=90:      ", prec_at_rec90)
print("Recall at precision=90:      ", rec_at_prec90)
print("AROC:                        ", auroc)
print("\n")

lambda_4b = "260.0"
with open(path4+'SSPicker_'+version+'_4b_'+lambda_4b+'_target_gen_auc.pickle', 'rb') as handle:
    auc = pickle.load(handle)
with open(path4+'SSPicker_'+version+'_4b_'+lambda_4b+'_target_gen_prec_at_rec90.pickle', 'rb') as handle:
    prec_at_rec90 = pickle.load(handle)
with open(path4+'SSPicker_'+version+'_4b_'+lambda_4b+'_target_gen_rec_at_prec90.pickle', 'rb') as handle:
    rec_at_prec90 = pickle.load(handle)
with open(path4+'SSPicker_'+version+'_4b_'+lambda_4b+'_target_gen_auroc.pickle', 'rb') as handle:
    auroc = pickle.load(handle)

print('crYOLO-v2')
print("AP:                          ", auc)
print("Precision at recall=90:      ", prec_at_rec90)
print("Recall at precision=90:      ", rec_at_prec90)
print("AROC:                        ", auroc)
print("\n")

lambda_4b = "270.0"
with open(path4+'SSPicker_'+version+'_4b_'+lambda_4b+'_target_gen_auc.pickle', 'rb') as handle:
    auc = pickle.load(handle)
with open(path4+'SSPicker_'+version+'_4b_'+lambda_4b+'_target_gen_prec_at_rec90.pickle', 'rb') as handle:
    prec_at_rec90 = pickle.load(handle)
with open(path4+'SSPicker_'+version+'_4b_'+lambda_4b+'_target_gen_rec_at_prec90.pickle', 'rb') as handle:
    rec_at_prec90 = pickle.load(handle)
with open(path4+'SSPicker_'+version+'_4b_'+lambda_4b+'_target_gen_auroc.pickle', 'rb') as handle:
    auroc = pickle.load(handle)

print('crYOLO-v2_filtered')
print("AP:                          ", auc)
print("Precision at recall=90:      ", prec_at_rec90)
print("Recall at precision=90:      ", rec_at_prec90)
print("AROC:                        ", auroc)
print("\n")


version = "23"
lambda_5b = "202.0"
with open(path4+'SSPicker_'+version+'_5b_'+lambda_5b+'_target_gen_auc.pickle', 'rb') as handle:
    auc = pickle.load(handle)
with open(path4+'SSPicker_'+version+'_5b_'+lambda_5b+'_target_gen_prec_at_rec90.pickle', 'rb') as handle:
    prec_at_rec90 = pickle.load(handle)
with open(path4+'SSPicker_'+version+'_5b_'+lambda_5b+'_target_gen_rec_at_prec90.pickle', 'rb') as handle:
    rec_at_prec90 = pickle.load(handle)
with open(path4+'SSPicker_'+version+'_5b_'+lambda_5b+'_target_gen_auroc.pickle', 'rb') as handle:
    auroc = pickle.load(handle)

print('Boxnet-old')
print("AP:                          ", auc)
print("Precision at recall=90:      ", prec_at_rec90)
print("Recall at precision=90:      ", rec_at_prec90)
print("AROC:                        ", auroc)

print("\n")

version = "29_1"
lambda_4b = "101.0"
with open(path4+'SSPicker_'+version+'_4b_'+lambda_4b+'_target_gen_auc.pickle', 'rb') as handle:
    auc = pickle.load(handle)
with open(path4+'SSPicker_'+version+'_4b_'+lambda_4b+'_target_gen_prec_at_rec90.pickle', 'rb') as handle:
    prec_at_rec90 = pickle.load(handle)
with open(path4+'SSPicker_'+version+'_4b_'+lambda_4b+'_target_gen_rec_at_prec90.pickle', 'rb') as handle:
    rec_at_prec90 = pickle.load(handle)
with open(path4+'SSPicker_'+version+'_4b_'+lambda_4b+'_target_gen_auroc.pickle', 'rb') as handle:
    auroc = pickle.load(handle)

print('Boxnet_unmasked')
print("AP:                          ", auc)
print("Precision at recall=90:      ", prec_at_rec90)
print("Recall at precision=90:      ", rec_at_prec90)
print("AROC:                        ", auroc)
print("\n")

version = "23"
with open(path4+'SSPicker_'+version+'_4c_'+lambda_4c+'_target_spec_auc.pickle', 'rb') as handle:
    auc = pickle.load(handle)
with open(path4+'SSPicker_'+version+'_4c_'+lambda_4c+'_target_spec_prec_at_rec90.pickle', 'rb') as handle:
    prec_at_rec90 = pickle.load(handle)
with open(path4+'SSPicker_'+version+'_4c_'+lambda_4c+'_target_spec_rec_at_prec90.pickle', 'rb') as handle:
    rec_at_prec90 = pickle.load(handle)
with open(path4+'SSPicker_'+version+'_4c_'+lambda_4c+'_target_spec_auroc.pickle', 'rb') as handle:
    auroc = pickle.load(handle)

    
print('HydraPicker-old')
print("AP:                          ", auc)
print("Precision at recall=90:      ", prec_at_rec90)
print("Recall at precision=90:      ", rec_at_prec90)
print("AROC:                        ", auroc)

print("\n")


version = "29_1"
lambda_4c = "0"
with open(path4+'SSPicker_'+version+'_4c_'+lambda_4c+'_target_spec_auc.pickle', 'rb') as handle:
    auc = pickle.load(handle)
with open(path4+'SSPicker_'+version+'_4c_'+lambda_4c+'_target_spec_prec_at_rec90.pickle', 'rb') as handle:
    prec_at_rec90 = pickle.load(handle)
with open(path4+'SSPicker_'+version+'_4c_'+lambda_4c+'_target_spec_rec_at_prec90.pickle', 'rb') as handle:
    rec_at_prec90 = pickle.load(handle)
with open(path4+'SSPicker_'+version+'_4c_'+lambda_4c+'_target_spec_auroc.pickle', 'rb') as handle:
    auroc = pickle.load(handle)

    
print('HydraPicker-new')
print("AP:                          ", auc)
print("Precision at recall=90:      ", prec_at_rec90)
print("Recall at precision=90:      ", rec_at_prec90)
print("AROC:                        ", auroc)

print("\n")


version = "23"
lambda_5b = "300.0"
with open(path4+'SSPicker_'+version+'_5b_'+lambda_5b+'_target_gen_auc.pickle', 'rb') as handle:
    auc = pickle.load(handle)
with open(path4+'SSPicker_'+version+'_5b_'+lambda_5b+'_target_gen_prec_at_rec90.pickle', 'rb') as handle:
    prec_at_rec90 = pickle.load(handle)
with open(path4+'SSPicker_'+version+'_5b_'+lambda_5b+'_target_gen_rec_at_prec90.pickle', 'rb') as handle:
    rec_at_prec90 = pickle.load(handle)
with open(path4+'SSPicker_'+version+'_5b_'+lambda_5b+'_target_gen_auroc.pickle', 'rb') as handle:
    auroc = pickle.load(handle)

print('7 models')
print("AP:                          ", auc)
print("Precision at recall=90:      ", prec_at_rec90)
print("Recall at precision=90:      ", rec_at_prec90)
print("AROC:                        ", auroc)

print("\n")
# Out:
# crYOLO-old
# AP:                           0.5897311510021634
# Precision at recall=90:       0.0
# Recall at precision=90:       0.21458923512747874
# AROC:                         0.7071926540523064
#
#
# crYOLO-v1
# AP:                           0.6038025645028897
# Precision at recall=90:       0.0
# Recall at precision=90:       0
# AROC:                         0.7538409154054813
#
#
# crYOLO-v1_filtered
# AP:                           0.48024108898788304
# Precision at recall=90:       0.0
# Recall at precision=90:       0.046742209631728045
# AROC:                         0.6341250688508456
#
#
# crYOLO-v2
# AP:                           0.22440145606530212
# Precision at recall=90:       0.0
# Recall at precision=90:       0
# AROC:                         0.6378768339149558
#
#
# crYOLO-v2_filtered
# AP:                           0.3438667627013171
# Precision at recall=90:       0.0
# Recall at precision=90:       0
# AROC:                         0.6612556175510662
#
#
# Boxnet-old
# AP:                           0.6699133966389139
# Precision at recall=90:       0.0
# Recall at precision=90:       0.06232294617563739
# AROC:                         0.8501433734458098
#
#
# Boxnet_unmasked
# AP:                           0.6757256839071909
# Precision at recall=90:       0.0
# Recall at precision=90:       0.07259206798866856
# AROC:                         0.8264393241227228
#
#
# HydraPicker-old
# AP:                           0.7813845182079207
# Precision at recall=90:       0.6017330691026717
# Recall at precision=90:       0.24291784702549576
# AROC:                         0.9479099767511304
#
#
# HydraPicker-new
# AP:                           0.8562131220831652
# Precision at recall=90:       0.7685981263960106
# Recall at precision=90:       0.5226628895184136
# AROC:                         0.9673048636018493
#
#
# 7 models
# AP:                           0.7700147448549054
# Precision at recall=90:       0.5475811827045053
# Recall at precision=90:       0.24256373937677056
# AROC:                         0.9338173672122527

# %%
version = "23"
# lambda_4a = "0.001"
# lambda_5a = "0.001"
lambda_4b = "3e-05"
lambda_5b = "101.0"
# lambda_5b = "200.0"
lambda_4c = "3e-05"
lambda_5c = "201.0"

# %% [markdown]
# # Specialized on training

# %%
with open(path4+'SSPicker_'+version+'_4b_'+lambda_4b+'_source_spec_rec2.pickle', 'rb') as handle:
    rec2_4b = pickle.load(handle)
with open(path4+'SSPicker_'+version+'_4b_'+lambda_4b+'_source_spec_prec2.pickle', 'rb') as handle:
    prec2_4b = pickle.load(handle)
with open(path4+'SSPicker_'+version+'_4b_'+lambda_4b+'_source_spec_fpr2.pickle', 'rb') as handle:
    fpr2_4b = pickle.load(handle)
with open(path4+'SSPicker_'+version+'_4b_'+lambda_4b+'_source_spec_rec3.pickle', 'rb') as handle:
    rec3_4b = pickle.load(handle)

lambda_5b = "101.0"
with open(path4+'SSPicker_'+version+'_5b_'+lambda_5b+'_target_gen_rec2.pickle', 'rb') as handle:
    rec2_5b_101 = pickle.load(handle)
with open(path4+'SSPicker_'+version+'_5b_'+lambda_5b+'_target_gen_prec2.pickle', 'rb') as handle:
    prec2_5b_101 = pickle.load(handle)
with open(path4+'SSPicker_'+version+'_5b_'+lambda_5b+'_target_gen_fpr2.pickle', 'rb') as handle:
    fpr2_5b_101 = pickle.load(handle)
with open(path4+'SSPicker_'+version+'_5b_'+lambda_5b+'_target_gen_rec3.pickle', 'rb') as handle:
    rec3_5b_101 = pickle.load(handle)

version = "29_1"    
lambda_5b = "123.0"
with open(path4+'SSPicker_'+version+'_5b_'+lambda_5b+'_target_gen_rec2.pickle', 'rb') as handle:
    rec2_5b_123 = pickle.load(handle)
with open(path4+'SSPicker_'+version+'_5b_'+lambda_5b+'_target_gen_prec2.pickle', 'rb') as handle:
    prec2_5b_123 = pickle.load(handle)
with open(path4+'SSPicker_'+version+'_5b_'+lambda_5b+'_target_gen_fpr2.pickle', 'rb') as handle:
    fpr2_5b_123 = pickle.load(handle)
with open(path4+'SSPicker_'+version+'_5b_'+lambda_5b+'_target_gen_rec3.pickle', 'rb') as handle:
    rec3_5b_123 = pickle.load(handle)
    
lambda_5b = "124.0"
with open(path4+'SSPicker_'+version+'_5b_'+lambda_5b+'_target_gen_rec2.pickle', 'rb') as handle:
    rec2_5b_124 = pickle.load(handle)
with open(path4+'SSPicker_'+version+'_5b_'+lambda_5b+'_target_gen_prec2.pickle', 'rb') as handle:
    prec2_5b_124 = pickle.load(handle)
with open(path4+'SSPicker_'+version+'_5b_'+lambda_5b+'_target_gen_fpr2.pickle', 'rb') as handle:
    fpr2_5b_124 = pickle.load(handle)
with open(path4+'SSPicker_'+version+'_5b_'+lambda_5b+'_target_gen_rec3.pickle', 'rb') as handle:
    rec3_5b_124 = pickle.load(handle)
    
lambda_5b = "125.0"
with open(path4+'SSPicker_'+version+'_5b_'+lambda_5b+'_target_gen_rec2.pickle', 'rb') as handle:
    rec2_5b_125 = pickle.load(handle)
with open(path4+'SSPicker_'+version+'_5b_'+lambda_5b+'_target_gen_prec2.pickle', 'rb') as handle:
    prec2_5b_125 = pickle.load(handle)
with open(path4+'SSPicker_'+version+'_5b_'+lambda_5b+'_target_gen_fpr2.pickle', 'rb') as handle:
    fpr2_5b_125 = pickle.load(handle)
with open(path4+'SSPicker_'+version+'_5b_'+lambda_5b+'_target_gen_rec3.pickle', 'rb') as handle:
    rec3_5b_125 = pickle.load(handle)

version = "29_1"
    
lambda_5b = "125.2"
with open(path4+'SSPicker_'+version+'_5b_'+lambda_5b+'_target_gen_rec2.pickle', 'rb') as handle:
    rec2_5b_cryolo_v1_new = pickle.load(handle)
with open(path4+'SSPicker_'+version+'_5b_'+lambda_5b+'_target_gen_prec2.pickle', 'rb') as handle:
    prec2_5b_cryolo_v1_new = pickle.load(handle)
with open(path4+'SSPicker_'+version+'_5b_'+lambda_5b+'_target_gen_fpr2.pickle', 'rb') as handle:
    fpr2_5b_cryolo_v1_new = pickle.load(handle)
with open(path4+'SSPicker_'+version+'_5b_'+lambda_5b+'_target_gen_rec3.pickle', 'rb') as handle:
    rec3_5b_cryolo_v1_new = pickle.load(handle)

lambda_4b = "202.0"
with open(path4+'SSPicker_'+version+'_4b_'+lambda_4b+'_target_gen_rec2.pickle', 'rb') as handle:
    rec2_4b_29_1_gen_cryolo_v1 = pickle.load(handle)
with open(path4+'SSPicker_'+version+'_4b_'+lambda_4b+'_target_gen_prec2.pickle', 'rb') as handle:
    prec2_4b_29_1_gen_cryolo_v1 = pickle.load(handle)
with open(path4+'SSPicker_'+version+'_4b_'+lambda_4b+'_target_gen_fpr2.pickle', 'rb') as handle:
    fpr2_4b_29_1_gen_cryolo_v1 = pickle.load(handle)
with open(path4+'SSPicker_'+version+'_4b_'+lambda_4b+'_target_gen_rec3.pickle', 'rb') as handle:
    rec3_4b_29_1_gen_cryolo_v1 = pickle.load(handle)
    
lambda_4b = "212.0"
with open(path4+'SSPicker_'+version+'_4b_'+lambda_4b+'_target_gen_rec2.pickle', 'rb') as handle:
    rec2_4b_29_1_gen_cryolo_v1_filtered = pickle.load(handle)
with open(path4+'SSPicker_'+version+'_4b_'+lambda_4b+'_target_gen_prec2.pickle', 'rb') as handle:
    prec2_4b_29_1_gen_cryolo_v1_filtered = pickle.load(handle)
with open(path4+'SSPicker_'+version+'_4b_'+lambda_4b+'_target_gen_fpr2.pickle', 'rb') as handle:
    fpr2_4b_29_1_gen_cryolo_v1_filtered = pickle.load(handle)
with open(path4+'SSPicker_'+version+'_4b_'+lambda_4b+'_target_gen_rec3.pickle', 'rb') as handle:
    rec3_4b_29_1_gen_cryolo_v1_filtered = pickle.load(handle)
    
lambda_4b = "222.0"
with open(path4+'SSPicker_'+version+'_4b_'+lambda_4b+'_target_gen_rec2.pickle', 'rb') as handle:
    rec2_4b_29_1_gen_cryolo_v2 = pickle.load(handle)
with open(path4+'SSPicker_'+version+'_4b_'+lambda_4b+'_target_gen_prec2.pickle', 'rb') as handle:
    prec2_4b_29_1_gen_cryolo_v2 = pickle.load(handle)
with open(path4+'SSPicker_'+version+'_4b_'+lambda_4b+'_target_gen_fpr2.pickle', 'rb') as handle:
    fpr2_4b_29_1_gen_cryolo_v2 = pickle.load(handle)
with open(path4+'SSPicker_'+version+'_4b_'+lambda_4b+'_target_gen_rec3.pickle', 'rb') as handle:
    rec3_4b_29_1_gen_cryolo_v2 = pickle.load(handle)
    
lambda_4b = "232.0"
with open(path4+'SSPicker_'+version+'_4b_'+lambda_4b+'_target_gen_rec2.pickle', 'rb') as handle:
    rec2_4b_29_1_gen_cryolo_v2_filtered = pickle.load(handle)
with open(path4+'SSPicker_'+version+'_4b_'+lambda_4b+'_target_gen_prec2.pickle', 'rb') as handle:
    prec2_4b_29_1_gen_cryolo_v2_filtered = pickle.load(handle)
with open(path4+'SSPicker_'+version+'_4b_'+lambda_4b+'_target_gen_fpr2.pickle', 'rb') as handle:
    fpr2_4b_29_1_gen_cryolo_v2_filtered = pickle.load(handle)
with open(path4+'SSPicker_'+version+'_4b_'+lambda_4b+'_target_gen_rec3.pickle', 'rb') as handle:
    rec3_4b_29_1_gen_cryolo_v2_filtered = pickle.load(handle)

lambda_4b = "102.0"
with open(path4+'SSPicker_'+version+'_4b_'+lambda_4b+'_target_gen_rec2.pickle', 'rb') as handle:
    rec2_4b_29_1_gen_boxnet_unmasked = pickle.load(handle)
with open(path4+'SSPicker_'+version+'_4b_'+lambda_4b+'_target_gen_prec2.pickle', 'rb') as handle:
    prec2_4b_29_1_gen_boxnet_unmasked = pickle.load(handle)
with open(path4+'SSPicker_'+version+'_4b_'+lambda_4b+'_target_gen_fpr2.pickle', 'rb') as handle:
    fpr2_4b_29_1_gen_boxnet_unmasked = pickle.load(handle)
with open(path4+'SSPicker_'+version+'_4b_'+lambda_4b+'_target_gen_rec3.pickle', 'rb') as handle:
    rec3_4b_29_1_gen_boxnet_unmasked = pickle.load(handle)
    
lambda_4b = "102.1"
with open(path4+'SSPicker_'+version+'_4b_'+lambda_4b+'_target_gen_rec2.pickle', 'rb') as handle:
    rec2_4b_29_1_gen_boxnet_unmasked2 = pickle.load(handle)
with open(path4+'SSPicker_'+version+'_4b_'+lambda_4b+'_target_gen_prec2.pickle', 'rb') as handle:
    prec2_4b_29_1_gen_boxnet_unmasked2 = pickle.load(handle)
with open(path4+'SSPicker_'+version+'_4b_'+lambda_4b+'_target_gen_fpr2.pickle', 'rb') as handle:
    fpr2_4b_29_1_gen_boxnet_unmasked2 = pickle.load(handle)
with open(path4+'SSPicker_'+version+'_4b_'+lambda_4b+'_target_gen_rec3.pickle', 'rb') as handle:
    rec3_4b_29_1_gen_boxnet_unmasked2 = pickle.load(handle)

lambda_4b = "122.0"
with open(path4+'SSPicker_'+version+'_4b_'+lambda_4b+'_target_gen_rec2.pickle', 'rb') as handle:
    rec2_4b_29_1_gen_boxnet_masked = pickle.load(handle)
with open(path4+'SSPicker_'+version+'_4b_'+lambda_4b+'_target_gen_prec2.pickle', 'rb') as handle:
    prec2_4b_29_1_gen_boxnet_masked = pickle.load(handle)
with open(path4+'SSPicker_'+version+'_4b_'+lambda_4b+'_target_gen_fpr2.pickle', 'rb') as handle:
    fpr2_4b_29_1_gen_boxnet_masked = pickle.load(handle)
with open(path4+'SSPicker_'+version+'_4b_'+lambda_4b+'_target_gen_rec3.pickle', 'rb') as handle:
    rec3_4b_29_1_gen_boxnet_masked = pickle.load(handle)

lambda_4b = "123.0"
with open(path4+'SSPicker_'+version+'_4b_'+lambda_4b+'_target_gen_rec2.pickle', 'rb') as handle:
    rec2_4b_29_1_gen_boxnet_masked2 = pickle.load(handle)
with open(path4+'SSPicker_'+version+'_4b_'+lambda_4b+'_target_gen_prec2.pickle', 'rb') as handle:
    prec2_4b_29_1_gen_boxnet_masked2 = pickle.load(handle)
with open(path4+'SSPicker_'+version+'_4b_'+lambda_4b+'_target_gen_fpr2.pickle', 'rb') as handle:
    fpr2_4b_29_1_gen_boxnet_masked2 = pickle.load(handle)
with open(path4+'SSPicker_'+version+'_4b_'+lambda_4b+'_target_gen_rec3.pickle', 'rb') as handle:
    rec3_4b_29_1_gen_boxnet_masked2 = pickle.load(handle)

# lambda_4b = "0"
# with open(path4+'SSPicker_'+version+'_4b_'+lambda_4b+'_source_gen_rec2.pickle', 'rb') as handle:
#     rec2_4b_29_1_gen = pickle.load(handle)
# with open(path4+'SSPicker_'+version+'_4b_'+lambda_4b+'_source_gen_prec2.pickle', 'rb') as handle:
#     prec2_4b_29_1_gen = pickle.load(handle)
# with open(path4+'SSPicker_'+version+'_4b_'+lambda_4b+'_source_gen_fpr2.pickle', 'rb') as handle:
#     fpr2_4b_29_1_gen = pickle.load(handle)
# with open(path4+'SSPicker_'+version+'_4b_'+lambda_4b+'_source_gen_rec3.pickle', 'rb') as handle:
#     rec3_4b_29_1_gen = pickle.load(handle)    


# with open(path4+'SSPicker_'+version+'_4b_'+lambda_4b+'_source_spec_rec2.pickle', 'rb') as handle:
#     rec2_4b_29_1_spec = pickle.load(handle)
# with open(path4+'SSPicker_'+version+'_4b_'+lambda_4b+'_source_spec_prec2.pickle', 'rb') as handle:
#     prec2_4b_29_1_spec = pickle.load(handle)
# with open(path4+'SSPicker_'+version+'_4b_'+lambda_4b+'_source_spec_fpr2.pickle', 'rb') as handle:
#     fpr2_4b_29_1_spec = pickle.load(handle)
# with open(path4+'SSPicker_'+version+'_4b_'+lambda_4b+'_source_spec_rec3.pickle', 'rb') as handle:
#     rec3_4b_29_1_spec = pickle.load(handle)
    
lambda_4b = "1.1"
with open(path4+'SSPicker_'+version+'_4b_'+lambda_4b+'_source_gen_rec2.pickle', 'rb') as handle:
    rec2_4b_29_1_gen = pickle.load(handle)
with open(path4+'SSPicker_'+version+'_4b_'+lambda_4b+'_source_gen_prec2.pickle', 'rb') as handle:
    prec2_4b_29_1_gen = pickle.load(handle)
with open(path4+'SSPicker_'+version+'_4b_'+lambda_4b+'_source_gen_fpr2.pickle', 'rb') as handle:
    fpr2_4b_29_1_gen = pickle.load(handle)
with open(path4+'SSPicker_'+version+'_4b_'+lambda_4b+'_source_gen_rec3.pickle', 'rb') as handle:
    rec3_4b_29_1_gen = pickle.load(handle)    


with open(path4+'SSPicker_'+version+'_4b_'+lambda_4b+'_source_spec_rec2.pickle', 'rb') as handle:
    rec2_4b_29_1_spec = pickle.load(handle)
with open(path4+'SSPicker_'+version+'_4b_'+lambda_4b+'_source_spec_prec2.pickle', 'rb') as handle:
    prec2_4b_29_1_spec = pickle.load(handle)
with open(path4+'SSPicker_'+version+'_4b_'+lambda_4b+'_source_spec_fpr2.pickle', 'rb') as handle:
    fpr2_4b_29_1_spec = pickle.load(handle)
with open(path4+'SSPicker_'+version+'_4b_'+lambda_4b+'_source_spec_rec3.pickle', 'rb') as handle:
    rec3_4b_29_1_spec = pickle.load(handle)  

version = "29_6"
lambda_4b = "1.1"
with open(path4+'SSPicker_'+version+'_4b_'+lambda_4b+'_source_gen_rec2.pickle', 'rb') as handle:
    rec2_4b_29_6_gen = pickle.load(handle)
with open(path4+'SSPicker_'+version+'_4b_'+lambda_4b+'_source_gen_prec2.pickle', 'rb') as handle:
    prec2_4b_29_6_gen = pickle.load(handle)
with open(path4+'SSPicker_'+version+'_4b_'+lambda_4b+'_source_gen_fpr2.pickle', 'rb') as handle:
    fpr2_4b_29_6_gen = pickle.load(handle)
with open(path4+'SSPicker_'+version+'_4b_'+lambda_4b+'_source_gen_rec3.pickle', 'rb') as handle:
    rec3_4b_29_6_gen = pickle.load(handle)    


with open(path4+'SSPicker_'+version+'_4b_'+lambda_4b+'_source_spec_rec2.pickle', 'rb') as handle:
    rec2_4b_29_6_spec = pickle.load(handle)
with open(path4+'SSPicker_'+version+'_4b_'+lambda_4b+'_source_spec_prec2.pickle', 'rb') as handle:
    prec2_4b_29_6_spec = pickle.load(handle)
with open(path4+'SSPicker_'+version+'_4b_'+lambda_4b+'_source_spec_fpr2.pickle', 'rb') as handle:
    fpr2_4b_29_6_spec = pickle.load(handle)
with open(path4+'SSPicker_'+version+'_4b_'+lambda_4b+'_source_spec_rec3.pickle', 'rb') as handle:
    rec3_4b_29_6_spec = pickle.load(handle)  

fig = p.figure()
ax = fig.gca()
ax.set_autoscale_on(False)
# ax.plot(rec2_4b_29_1_gen_cryolo_v1, prec2_4b_29_1_gen_cryolo_v1, label='crYOLO')
# ax.plot(rec2_4b_29_1_gen_cryolo_v1_filtered, prec2_4b_29_1_gen_cryolo_v1_filtered, label='crYOLO-v1_filtered')
# ax.plot(rec2_4b_29_1_gen_cryolo_v2, prec2_4b_29_1_gen_cryolo_v2, label='crYOLO-v2')
# ax.plot(rec2_4b_29_1_gen_cryolo_v2_filtered, prec2_4b_29_1_gen_cryolo_v2_filtered, label='crYOLO-v2_filtered')
# ax.plot(rec2_4b_29_1_gen_boxnet_unmasked, prec2_4b_29_1_gen_boxnet_unmasked, label='boxnet')
# ax.plot(rec2_4b_29_1_gen_boxnet_masked, prec2_4b_29_1_gen_boxnet_masked, label='boxnet_mask')
# ax.plot(rec2_5b_101, prec2_5b_101, label='HydraPicker-old_gen')
# ax.plot(rec2_4b, prec2_4b, label='HydraPicker-old_spec')
# ax.plot(rec2_5b_125, prec2_5b_125, label='crYOLO_v1')
ax.plot(rec2_5b_cryolo_v1_new, prec2_5b_cryolo_v1_new, label='crYOLO')
# ax.plot(rec2_5b_124, prec2_5b_124, label='boxnet_unmasked_old')
ax.plot(rec2_4b_29_1_gen_boxnet_unmasked2, prec2_4b_29_1_gen_boxnet_unmasked2, label='boxnet')
# ax.plot(rec2_5b_123, prec2_5b_123, label='boxnet_masked_provided')
ax.plot(rec2_4b_29_1_gen_boxnet_masked2, prec2_4b_29_1_gen_boxnet_masked2, label='boxnet_masked')
# ax.plot(rec2_4b_29_1_gen, prec2_4b_29_1_gen, label='HydraPicker_gen_old')
ax.plot(rec2_4b_29_6_gen, prec2_4b_29_6_gen, label='HydraPicker_gen')
# ax.plot(rec2_4b_29_1_spec, prec2_4b_29_1_spec, label='HydraPicker_spec_old')
ax.plot(rec2_4b_29_6_spec, prec2_4b_29_6_spec, label='HydraPicker_spec')
ax.axis([0,1,0,1])
ax.set(xlabel='Recall', ylabel='Precision')
ax.grid()
ax.legend()


fig = p.figure()
ax = fig.gca()
ax.set_autoscale_on(False)
# ax.plot(fpr2_4b_29_1_gen_cryolo_v1, rec3_4b_29_1_gen_cryolo_v1, label='crYOLO')
# ax.plot(fpr2_4b_29_1_gen_cryolo_v1_filtered, rec3_4b_29_1_gen_cryolo_v1_filtered, label='crYOLO-v1_filtered')
# ax.plot(fpr2_4b_29_1_gen_cryolo_v2, rec3_4b_29_1_gen_cryolo_v2, label='crYOLO-v2')
# ax.plot(fpr2_4b_29_1_gen_cryolo_v2_filtered, rec3_4b_29_1_gen_cryolo_v2_filtered, label='crYOLO-v2_filtered')
# ax.plot(fpr2_4b_29_1_gen_boxnet_unmasked, rec3_4b_29_1_gen_boxnet_unmasked, label='boxnet')
# ax.plot(fpr2_4b_29_1_gen_boxnet_masked, rec3_4b_29_1_gen_boxnet_masked, label='boxnet_mask')
# ax.plot(fpr2_5b_101, rec3_5b_101, label='HydraPicker-old_gen')
# ax.plot(fpr2_4b, rec3_4b, label='HydraPicker-old_spec')
# ax.plot(fpr2_5b_125, rec3_5b_125, label='crYOLO_v1')
ax.plot(fpr2_5b_cryolo_v1_new, rec3_5b_cryolo_v1_new, label='crYOLO')
# ax.plot(fpr2_5b_124, rec3_5b_124, label='boxnet_unmasked_old')
ax.plot(fpr2_4b_29_1_gen_boxnet_unmasked2, rec3_4b_29_1_gen_boxnet_unmasked2, label='boxnet')
# ax.plot(fpr2_5b_123, rec3_5b_123, label='boxnet_masked_provided')
ax.plot(fpr2_4b_29_1_gen_boxnet_masked2, rec3_4b_29_1_gen_boxnet_masked2, label='boxnet_masked')
# ax.plot(fpr2_4b_29_1_gen, rec3_4b_29_1_gen, label='HydraPicker_gen_old')
ax.plot(fpr2_4b_29_6_gen, rec3_4b_29_6_gen, label='HydraPicker_gen')
# ax.plot(fpr2_4b_29_1_spec, rec3_4b_29_1_spec, label='HydraPicker_spec_old')
ax.plot(fpr2_4b_29_6_spec, rec3_4b_29_6_spec, label='HydraPicker_spec')
ax.axis([0,1,0,1])
ax.set(xlabel='False-Positive Rate', ylabel='Recall')
ax.grid()
ax.legend()

# %%
version = "29_1"
lambda_4b = "202.0"
with open(path4+'SSPicker_'+version+'_4b_'+lambda_4b+'_target_gen_auc.pickle', 'rb') as handle:
    auc = pickle.load(handle)
with open(path4+'SSPicker_'+version+'_4b_'+lambda_4b+'_target_gen_prec_at_rec90.pickle', 'rb') as handle:
    prec_at_rec90 = pickle.load(handle)
with open(path4+'SSPicker_'+version+'_4b_'+lambda_4b+'_target_gen_rec_at_prec90.pickle', 'rb') as handle:
    rec_at_prec90 = pickle.load(handle)
with open(path4+'SSPicker_'+version+'_4b_'+lambda_4b+'_target_gen_auroc.pickle', 'rb') as handle:
    auroc = pickle.load(handle)

print('crYOLO-v1')
print("AP:                          ", auc)
print("Precision at recall=90:      ", prec_at_rec90)
print("Recall at precision=90:      ", rec_at_prec90)
print("AROC:                        ", auroc)
print("\n")

lambda_4b = "212.0"
with open(path4+'SSPicker_'+version+'_4b_'+lambda_4b+'_target_gen_auc.pickle', 'rb') as handle:
    auc = pickle.load(handle)
with open(path4+'SSPicker_'+version+'_4b_'+lambda_4b+'_target_gen_prec_at_rec90.pickle', 'rb') as handle:
    prec_at_rec90 = pickle.load(handle)
with open(path4+'SSPicker_'+version+'_4b_'+lambda_4b+'_target_gen_rec_at_prec90.pickle', 'rb') as handle:
    rec_at_prec90 = pickle.load(handle)
with open(path4+'SSPicker_'+version+'_4b_'+lambda_4b+'_target_gen_auroc.pickle', 'rb') as handle:
    auroc = pickle.load(handle)

print('crYOLO-v1-filtered')
print("AP:                          ", auc)
print("Precision at recall=90:      ", prec_at_rec90)
print("Recall at precision=90:      ", rec_at_prec90)
print("AROC:                        ", auroc)
print("\n")

lambda_4b = "222.0"
with open(path4+'SSPicker_'+version+'_4b_'+lambda_4b+'_target_gen_auc.pickle', 'rb') as handle:
    auc = pickle.load(handle)
with open(path4+'SSPicker_'+version+'_4b_'+lambda_4b+'_target_gen_prec_at_rec90.pickle', 'rb') as handle:
    prec_at_rec90 = pickle.load(handle)
with open(path4+'SSPicker_'+version+'_4b_'+lambda_4b+'_target_gen_rec_at_prec90.pickle', 'rb') as handle:
    rec_at_prec90 = pickle.load(handle)
with open(path4+'SSPicker_'+version+'_4b_'+lambda_4b+'_target_gen_auroc.pickle', 'rb') as handle:
    auroc = pickle.load(handle)

print('crYOLO-v2')
print("AP:                          ", auc)
print("Precision at recall=90:      ", prec_at_rec90)
print("Recall at precision=90:      ", rec_at_prec90)
print("AROC:                        ", auroc)
print("\n")

lambda_4b = "232.0"
with open(path4+'SSPicker_'+version+'_4b_'+lambda_4b+'_target_gen_auc.pickle', 'rb') as handle:
    auc = pickle.load(handle)
with open(path4+'SSPicker_'+version+'_4b_'+lambda_4b+'_target_gen_prec_at_rec90.pickle', 'rb') as handle:
    prec_at_rec90 = pickle.load(handle)
with open(path4+'SSPicker_'+version+'_4b_'+lambda_4b+'_target_gen_rec_at_prec90.pickle', 'rb') as handle:
    rec_at_prec90 = pickle.load(handle)
with open(path4+'SSPicker_'+version+'_4b_'+lambda_4b+'_target_gen_auroc.pickle', 'rb') as handle:
    auroc = pickle.load(handle)

print('crYOLO-v2-filtered')
print("AP:                          ", auc)
print("Precision at recall=90:      ", prec_at_rec90)
print("Recall at precision=90:      ", rec_at_prec90)
print("AROC:                        ", auroc)
print("\n")


lambda_4b = "102.0"
with open(path4+'SSPicker_'+version+'_4b_'+lambda_4b+'_target_gen_auc.pickle', 'rb') as handle:
    auc = pickle.load(handle)
with open(path4+'SSPicker_'+version+'_4b_'+lambda_4b+'_target_gen_prec_at_rec90.pickle', 'rb') as handle:
    prec_at_rec90 = pickle.load(handle)
with open(path4+'SSPicker_'+version+'_4b_'+lambda_4b+'_target_gen_rec_at_prec90.pickle', 'rb') as handle:
    rec_at_prec90 = pickle.load(handle)
with open(path4+'SSPicker_'+version+'_4b_'+lambda_4b+'_target_gen_auroc.pickle', 'rb') as handle:
    auroc = pickle.load(handle)

print('Boxnet-unmasked')
print("AP:                          ", auc)
print("Precision at recall=90:      ", prec_at_rec90)
print("Recall at precision=90:      ", rec_at_prec90)
print("AROC:                        ", auroc)
print("\n")

lambda_4b = "122.0"
with open(path4+'SSPicker_'+version+'_4b_'+lambda_4b+'_target_gen_auc.pickle', 'rb') as handle:
    auc = pickle.load(handle)
with open(path4+'SSPicker_'+version+'_4b_'+lambda_4b+'_target_gen_prec_at_rec90.pickle', 'rb') as handle:
    prec_at_rec90 = pickle.load(handle)
with open(path4+'SSPicker_'+version+'_4b_'+lambda_4b+'_target_gen_rec_at_prec90.pickle', 'rb') as handle:
    rec_at_prec90 = pickle.load(handle)
with open(path4+'SSPicker_'+version+'_4b_'+lambda_4b+'_target_gen_auroc.pickle', 'rb') as handle:
    auroc = pickle.load(handle)

print('Boxnet-masked')
print("AP:                          ", auc)
print("Precision at recall=90:      ", prec_at_rec90)
print("Recall at precision=90:      ", rec_at_prec90)
print("AROC:                        ", auroc)
print("\n")

version = "23"
# lambda_4a = "0.001"
# lambda_5a = "0.001"
lambda_4b = "3e-05"
lambda_5b = "101.0"
# lambda_5b = "200.0"
lambda_4c = "3e-05"
lambda_5c = "201.0"

with open(path4+'SSPicker_'+version+'_4b_'+lambda_4b+'_source_spec_auc.pickle', 'rb') as handle:
    auc = pickle.load(handle)
with open(path4+'SSPicker_'+version+'_4b_'+lambda_4b+'_source_spec_prec_at_rec90.pickle', 'rb') as handle:
    prec_at_rec90 = pickle.load(handle)
with open(path4+'SSPicker_'+version+'_4b_'+lambda_4b+'_source_spec_rec_at_prec90.pickle', 'rb') as handle:
    rec_at_prec90 = pickle.load(handle)
with open(path4+'SSPicker_'+version+'_4b_'+lambda_4b+'_source_spec_auroc.pickle', 'rb') as handle:
    auroc = pickle.load(handle)

print('HydraPicker-old_gen')
print("AP:                          ", auc)
print("Precision at recall=90:      ", prec_at_rec90)
print("Recall at precision=90:      ", rec_at_prec90)
print("AROC:                        ", auroc)

print("\n")

with open(path4+'SSPicker_'+version+'_5b_'+lambda_5b+'_target_gen_auc.pickle', 'rb') as handle:
    auc = pickle.load(handle)
with open(path4+'SSPicker_'+version+'_5b_'+lambda_5b+'_target_gen_prec_at_rec90.pickle', 'rb') as handle:
    prec_at_rec90 = pickle.load(handle)
with open(path4+'SSPicker_'+version+'_5b_'+lambda_5b+'_target_gen_rec_at_prec90.pickle', 'rb') as handle:
    rec_at_prec90 = pickle.load(handle)
with open(path4+'SSPicker_'+version+'_5b_'+lambda_5b+'_target_gen_auroc.pickle', 'rb') as handle:
    auroc = pickle.load(handle)

print('HydraPicker-old_spec')
print("AP:                          ", auc)
print("Precision at recall=90:      ", prec_at_rec90)
print("Recall at precision=90:      ", rec_at_prec90)
print("AROC:                        ", auroc)

print("\n")

version = "29_1"
lambda_4b = "1.1"

with open(path4+'SSPicker_'+version+'_4b_'+lambda_4b+'_source_gen_auc.pickle', 'rb') as handle:
    auc = pickle.load(handle)
with open(path4+'SSPicker_'+version+'_4b_'+lambda_4b+'_source_gen_prec_at_rec90.pickle', 'rb') as handle:
    prec_at_rec90 = pickle.load(handle)
with open(path4+'SSPicker_'+version+'_4b_'+lambda_4b+'_source_gen_rec_at_prec90.pickle', 'rb') as handle:
    rec_at_prec90 = pickle.load(handle)
with open(path4+'SSPicker_'+version+'_4b_'+lambda_4b+'_source_gen_auroc.pickle', 'rb') as handle:
    auroc = pickle.load(handle)

print('HydraPicker-new_gen')
print("AP:                          ", auc)
print("Precision at recall=90:      ", prec_at_rec90)
print("Recall at precision=90:      ", rec_at_prec90)
print("AROC:                        ", auroc)

print("\n")

with open(path4+'SSPicker_'+version+'_4b_'+lambda_4b+'_source_spec_auc.pickle', 'rb') as handle:
    auc = pickle.load(handle)
with open(path4+'SSPicker_'+version+'_4b_'+lambda_4b+'_source_spec_prec_at_rec90.pickle', 'rb') as handle:
    prec_at_rec90 = pickle.load(handle)
with open(path4+'SSPicker_'+version+'_4b_'+lambda_4b+'_source_spec_rec_at_prec90.pickle', 'rb') as handle:
    rec_at_prec90 = pickle.load(handle)
with open(path4+'SSPicker_'+version+'_4b_'+lambda_4b+'_source_spec_auroc.pickle', 'rb') as handle:
    auroc = pickle.load(handle)

print('HydraPicker-new_spec')
print("AP:                          ", auc)
print("Precision at recall=90:      ", prec_at_rec90)
print("Recall at precision=90:      ", rec_at_prec90)
print("AROC:                        ", auroc)

print("\n")


version = "29_1"
lambda_5b = "123.0"
with open(path4+'SSPicker_'+version+'_5b_'+lambda_5b+'_target_gen_auc.pickle', 'rb') as handle:
    auc = pickle.load(handle)
with open(path4+'SSPicker_'+version+'_5b_'+lambda_5b+'_target_gen_prec_at_rec90.pickle', 'rb') as handle:
    prec_at_rec90 = pickle.load(handle)
with open(path4+'SSPicker_'+version+'_5b_'+lambda_5b+'_target_gen_rec_at_prec90.pickle', 'rb') as handle:
    rec_at_prec90 = pickle.load(handle)
with open(path4+'SSPicker_'+version+'_5b_'+lambda_5b+'_target_gen_auroc.pickle', 'rb') as handle:
    auroc = pickle.load(handle)

print('Boxnet_masked')
print("AP:                          ", auc)
print("Precision at recall=90:      ", prec_at_rec90)
print("Recall at precision=90:      ", rec_at_prec90)
print("AROC:                        ", auroc)

print("\n")

lambda_5b = "124.0"
with open(path4+'SSPicker_'+version+'_5b_'+lambda_5b+'_target_gen_auc.pickle', 'rb') as handle:
    auc = pickle.load(handle)
with open(path4+'SSPicker_'+version+'_5b_'+lambda_5b+'_target_gen_prec_at_rec90.pickle', 'rb') as handle:
    prec_at_rec90 = pickle.load(handle)
with open(path4+'SSPicker_'+version+'_5b_'+lambda_5b+'_target_gen_rec_at_prec90.pickle', 'rb') as handle:
    rec_at_prec90 = pickle.load(handle)
with open(path4+'SSPicker_'+version+'_5b_'+lambda_5b+'_target_gen_auroc.pickle', 'rb') as handle:
    auroc = pickle.load(handle)

print('Boxnet')
print("AP:                          ", auc)
print("Precision at recall=90:      ", prec_at_rec90)
print("Recall at precision=90:      ", rec_at_prec90)
print("AROC:                        ", auroc)

print("\n")


lambda_5b = "125.0"
with open(path4+'SSPicker_'+version+'_5b_'+lambda_5b+'_target_gen_auc.pickle', 'rb') as handle:
    auc = pickle.load(handle)
with open(path4+'SSPicker_'+version+'_5b_'+lambda_5b+'_target_gen_prec_at_rec90.pickle', 'rb') as handle:
    prec_at_rec90 = pickle.load(handle)
with open(path4+'SSPicker_'+version+'_5b_'+lambda_5b+'_target_gen_rec_at_prec90.pickle', 'rb') as handle:
    rec_at_prec90 = pickle.load(handle)
with open(path4+'SSPicker_'+version+'_5b_'+lambda_5b+'_target_gen_auroc.pickle', 'rb') as handle:
    auroc = pickle.load(handle)

print('crYOLO')
print("AP:                          ", auc)
print("Precision at recall=90:      ", prec_at_rec90)
print("Recall at precision=90:      ", rec_at_prec90)
print("AROC:                        ", auroc)

print("\n")
# Out:
# crYOLO-v1
# AP:                           0.34616544030644025
# Precision at recall=90:       0.0
# Recall at precision=90:       0
# AROC:                         0.5727154178912442
#
#
# crYOLO-v1-filtered
# AP:                           0.22387860425430522
# Precision at recall=90:       0.0
# Recall at precision=90:       0
# AROC:                         0.4805928802501203
#
#
# crYOLO-v2
# AP:                           0.29232963932907247
# Precision at recall=90:       0.0
# Recall at precision=90:       0
# AROC:                         0.5304102397476994
#
#
# crYOLO-v2-filtered
# AP:                           0.14324867417412607
# Precision at recall=90:       0.0
# Recall at precision=90:       0
# AROC:                         0.44124100800442523
#
#
# Boxnet-unmasked
# AP:                           0.2979354953551697
# Precision at recall=90:       0.0
# Recall at precision=90:       0.00022842784535434868
# AROC:                         0.5055515003937273
#
#
# Boxnet-masked
# AP:                           0.320539875164224
# Precision at recall=90:       0.0
# Recall at precision=90:       0.018673976357718006
# AROC:                         0.47655891273802
#
#
# HydraPicker-old_gen
# AP:                           0.7975556280870933
# Precision at recall=90:       0.5827736884847423
# Recall at precision=90:       0.36231884057971014
# AROC:                         0.9302713426303785
#
#
# HydraPicker-old_spec
# AP:                           0.7793053651871034
# Precision at recall=90:       0.5278263003729011
# Recall at precision=90:       0.30870697463768115
# AROC:                         0.916713681275327
#
#
# HydraPicker-new_gen
# AP:                           0.8748575594390955
# Precision at recall=90:       0.7773645430779045
# Recall at precision=90:       0.5759808120609903
# AROC:                         0.9602154178660735
#
#
# HydraPicker-new_spec
# AP:                           0.8780734326073614
# Precision at recall=90:       0.7801425460304889
# Recall at precision=90:       0.5806064759294158
# AROC:                         0.961688287054425
#
#
# Boxnet_masked
# AP:                           0.644623158526554
# Precision at recall=90:       0.0
# Recall at precision=90:       0.3557192621780595
# AROC:                         0.7142638836559683
#
#
# Boxnet
# AP:                           0.2819429926660313
# Precision at recall=90:       0.0
# Recall at precision=90:       0
# AROC:                         0.4779040776670376
#
#
# crYOLO
# AP:                           0.7151886744499997
# Precision at recall=90:       0.0
# Recall at precision=90:       0.32585232139797843
# AROC:                         0.8307418377303388
