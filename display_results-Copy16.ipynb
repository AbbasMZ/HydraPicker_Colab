# %%
# %matplotlib inline
# %reload_ext autoreload
# %autoreload 2

# %%
import sys, os
import pickle
import imageio
import numpy as np
from skimage import measure

# sys.path.append('../')
# from fastai.conv_learner import *
from fastai.dataset import *

from pathlib import Path
import json
from PIL import ImageDraw, ImageFont
from matplotlib import patches, patheffects

# check to make sure you set the device
# cuda_id = 1
# torch.cuda.set_device(cuda_id)

import pylab as p
from pylab import rcParams
rcParams['figure.figsize'] = 12, 12
rcParams.update({'font.size': 38})
rcParams['lines.linewidth'] = 6
rcParams['legend.loc'] = 'lower left'
rcParams['legend.framealpha'] = 0.5

# %%
############ Useful paths
# path1='data/boxnet/trainingdata/'
# files_list = os.listdir(path1)
# path2 = 'data/boxnet/trainingdata2/'
# path3 = 'data/boxnet/labels/'
path4 = 'data/boxnet/results/'
# PATH = Path('data/boxnet')
# IMAGES = 'trainingdata2'

# %%
version = "23"
# lambda_4a = "0.001"
# lambda_5a = "0.001"
lambda_4b = "0"
lambda_5b = "200.0"
lambda_4c = "1.0"
lambda_5c = "201.0"

# %%
# version = "23"
# # lambda_4a = "0.001"
# # lambda_5a = "0.001"
# lambda_4b = "3e-05"
# lambda_5b = "101.0"
# # lambda_5b = "200.0"
# lambda_4c = "3e-05"
# lambda_5c = "201.0"

# with open(path4+'SSPicker_'+version+'_5b_'+lambda_5b+'_target_gen_auc.pickle', 'rb') as handle:
#     auc = pickle.load(handle)
# with open(path4+'SSPicker_'+version+'_5b_'+lambda_5b+'_target_gen_prec_at_rec90.pickle', 'rb') as handle:
#     prec_at_rec90 = pickle.load(handle)
# with open(path4+'SSPicker_'+version+'_5b_'+lambda_5b+'_target_gen_rec_at_prec90.pickle', 'rb') as handle:
#     rec_at_prec90 = pickle.load(handle)
# with open(path4+'SSPicker_'+version+'_5b_'+lambda_5b+'_target_gen_auroc.pickle', 'rb') as handle:
#     auroc = pickle.load(handle)

# print('HydraPicker: Tested with generic head')
# print("AP:                          ", auc)
# print("Precision at recall=90:      ", prec_at_rec90)
# print("Recall at precision=90:      ", rec_at_prec90)
# print("AROC:                        ", auroc)

# print("\n")

# %% [markdown]
# # 2wri

# %%
version = "29_6"

lambda_4c = "1001.1"
with open(path4+'SSPicker_'+version+'_4c_'+lambda_4c+'_target_gen_rec2.pickle', 'rb') as handle:
    rec2_cryolo_2wri = pickle.load(handle)
with open(path4+'SSPicker_'+version+'_4c_'+lambda_4c+'_target_gen_prec2.pickle', 'rb') as handle:
    prec2_cryolo_2wri = pickle.load(handle)
with open(path4+'SSPicker_'+version+'_4c_'+lambda_4c+'_target_gen_fpr2.pickle', 'rb') as handle:
    fpr2_cryolo_2wri = pickle.load(handle)
with open(path4+'SSPicker_'+version+'_4c_'+lambda_4c+'_target_gen_rec3.pickle', 'rb') as handle:
    rec3_cryolo_2wri = pickle.load(handle) 

# lambda_4c = "1002.1"
# with open(path4+'SSPicker_'+version+'_4c_'+lambda_4c+'_target_gen_rec2.pickle', 'rb') as handle:
#     rec2_boxnet_2wri = pickle.load(handle)
# with open(path4+'SSPicker_'+version+'_4c_'+lambda_4c+'_target_gen_prec2.pickle', 'rb') as handle:
#     prec2_boxnet_2wri = pickle.load(handle)
# with open(path4+'SSPicker_'+version+'_4c_'+lambda_4c+'_target_gen_fpr2.pickle', 'rb') as handle:
#     fpr2_boxnet_2wri = pickle.load(handle)
# with open(path4+'SSPicker_'+version+'_4c_'+lambda_4c+'_target_gen_rec3.pickle', 'rb') as handle:
#     rec3_boxnet_2wri = pickle.load(handle)
    
lambda_4c = "1003.1"
with open(path4+'SSPicker_'+version+'_4c_'+lambda_4c+'_target_gen_rec2.pickle', 'rb') as handle:
    rec2_boxnet_masked_2wri = pickle.load(handle)
with open(path4+'SSPicker_'+version+'_4c_'+lambda_4c+'_target_gen_prec2.pickle', 'rb') as handle:
    prec2_boxnet_masked_2wri = pickle.load(handle)
with open(path4+'SSPicker_'+version+'_4c_'+lambda_4c+'_target_gen_fpr2.pickle', 'rb') as handle:
    fpr2_boxnet_masked_2wri = pickle.load(handle)
with open(path4+'SSPicker_'+version+'_4c_'+lambda_4c+'_target_gen_rec3.pickle', 'rb') as handle:
    rec3_boxnet_masked_2wri = pickle.load(handle) 

# lambda_4c = "1004.1"
# with open(path4+'SSPicker_'+version+'_4c_'+lambda_4c+'_target_gen_rec2.pickle', 'rb') as handle:
#     rec2_7_models_2wri = pickle.load(handle)
# with open(path4+'SSPicker_'+version+'_4c_'+lambda_4c+'_target_gen_prec2.pickle', 'rb') as handle:
#     prec2_7_models_2wri = pickle.load(handle)
# with open(path4+'SSPicker_'+version+'_4c_'+lambda_4c+'_target_gen_fpr2.pickle', 'rb') as handle:
#     fpr2_7_models_2wri = pickle.load(handle)
# with open(path4+'SSPicker_'+version+'_4c_'+lambda_4c+'_target_gen_rec3.pickle', 'rb') as handle:
#     rec3_7_models_2wri = pickle.load(handle) 
    
lambda_4c = "1005.1"
with open(path4+'SSPicker_'+version+'_4c_'+lambda_4c+'_target_spec_rec2.pickle', 'rb') as handle:
    rec2_hydra_2wri = pickle.load(handle)
with open(path4+'SSPicker_'+version+'_4c_'+lambda_4c+'_target_spec_prec2.pickle', 'rb') as handle:
    prec2_hydra_2wri = pickle.load(handle)
with open(path4+'SSPicker_'+version+'_4c_'+lambda_4c+'_target_spec_fpr2.pickle', 'rb') as handle:
    fpr2_hydra_2wri = pickle.load(handle)
with open(path4+'SSPicker_'+version+'_4c_'+lambda_4c+'_target_spec_rec3.pickle', 'rb') as handle:
    rec3_hydra_2wri = pickle.load(handle)


fig = p.figure()
ax = fig.gca()
ax.set_autoscale_on(False)
ax.plot(rec2_cryolo_2wri, prec2_cryolo_2wri, label='crYOLO')
# ax.plot(rec2_boxnet_2wri, prec2_boxnet_2wri, label='Boxnet')
ax.plot(rec2_boxnet_masked_2wri, prec2_boxnet_masked_2wri, label='Boxnet_masked')
# ax.plot(rec2_7_models_2wri, prec2_7_models_2wri, label='7 models')
ax.plot(rec2_hydra_2wri, prec2_hydra_2wri, label='HydraPicker')
ax.axis([0,1,0,1])
ax.set(xlabel='Recall', ylabel='Precision')
ax.grid()
ax.legend()

fig = p.figure()
ax = fig.gca()
ax.set_autoscale_on(False)
ax.plot(fpr2_cryolo_2wri, rec3_cryolo_2wri, label='crYOLO')
# ax.plot(fpr2_boxnet_2wri, rec3_boxnet_2wri, label='Boxnet')
ax.plot(fpr2_boxnet_masked_2wri, rec3_boxnet_masked_2wri, label='Boxnet_masked')
# ax.plot(fpr2_7_models_2wri, rec3_7_models_2wri, label='7 models')
ax.plot(fpr2_hydra_2wri, rec3_hydra_2wri, label='HydraPicker')
ax.axis([0,1,0,1])
ax.set(xlabel='False-Positive Rate', ylabel='Recall')
ax.grid()
ax.legend()

# %% [markdown]
# # 4HHB

# %%
version = "29_6"

lambda_4c = "1001.2"
with open(path4+'SSPicker_'+version+'_4c_'+lambda_4c+'_target_gen_rec2.pickle', 'rb') as handle:
    rec2_cryolo_2wri = pickle.load(handle)
with open(path4+'SSPicker_'+version+'_4c_'+lambda_4c+'_target_gen_prec2.pickle', 'rb') as handle:
    prec2_cryolo_2wri = pickle.load(handle)
with open(path4+'SSPicker_'+version+'_4c_'+lambda_4c+'_target_gen_fpr2.pickle', 'rb') as handle:
    fpr2_cryolo_2wri = pickle.load(handle)
with open(path4+'SSPicker_'+version+'_4c_'+lambda_4c+'_target_gen_rec3.pickle', 'rb') as handle:
    rec3_cryolo_2wri = pickle.load(handle) 

# lambda_4c = "1002.2"
# with open(path4+'SSPicker_'+version+'_4c_'+lambda_4c+'_target_gen_rec2.pickle', 'rb') as handle:
#     rec2_boxnet_2wri = pickle.load(handle)
# with open(path4+'SSPicker_'+version+'_4c_'+lambda_4c+'_target_gen_prec2.pickle', 'rb') as handle:
#     prec2_boxnet_2wri = pickle.load(handle)
# with open(path4+'SSPicker_'+version+'_4c_'+lambda_4c+'_target_gen_fpr2.pickle', 'rb') as handle:
#     fpr2_boxnet_2wri = pickle.load(handle)
# with open(path4+'SSPicker_'+version+'_4c_'+lambda_4c+'_target_gen_rec3.pickle', 'rb') as handle:
#     rec3_boxnet_2wri = pickle.load(handle)
    
lambda_4c = "1003.2"
with open(path4+'SSPicker_'+version+'_4c_'+lambda_4c+'_target_gen_rec2.pickle', 'rb') as handle:
    rec2_boxnet_masked_2wri = pickle.load(handle)
with open(path4+'SSPicker_'+version+'_4c_'+lambda_4c+'_target_gen_prec2.pickle', 'rb') as handle:
    prec2_boxnet_masked_2wri = pickle.load(handle)
with open(path4+'SSPicker_'+version+'_4c_'+lambda_4c+'_target_gen_fpr2.pickle', 'rb') as handle:
    fpr2_boxnet_masked_2wri = pickle.load(handle)
with open(path4+'SSPicker_'+version+'_4c_'+lambda_4c+'_target_gen_rec3.pickle', 'rb') as handle:
    rec3_boxnet_masked_2wri = pickle.load(handle) 

# lambda_4c = "1004.2"
# with open(path4+'SSPicker_'+version+'_4c_'+lambda_4c+'_target_gen_rec2.pickle', 'rb') as handle:
#     rec2_7_models_2wri = pickle.load(handle)
# with open(path4+'SSPicker_'+version+'_4c_'+lambda_4c+'_target_gen_prec2.pickle', 'rb') as handle:
#     prec2_7_models_2wri = pickle.load(handle)
# with open(path4+'SSPicker_'+version+'_4c_'+lambda_4c+'_target_gen_fpr2.pickle', 'rb') as handle:
#     fpr2_7_models_2wri = pickle.load(handle)
# with open(path4+'SSPicker_'+version+'_4c_'+lambda_4c+'_target_gen_rec3.pickle', 'rb') as handle:
#     rec3_7_models_2wri = pickle.load(handle) 
    
lambda_4c = "1005.2"
with open(path4+'SSPicker_'+version+'_4c_'+lambda_4c+'_target_spec_rec2.pickle', 'rb') as handle:
    rec2_hydra_2wri = pickle.load(handle)
with open(path4+'SSPicker_'+version+'_4c_'+lambda_4c+'_target_spec_prec2.pickle', 'rb') as handle:
    prec2_hydra_2wri = pickle.load(handle)
with open(path4+'SSPicker_'+version+'_4c_'+lambda_4c+'_target_spec_fpr2.pickle', 'rb') as handle:
    fpr2_hydra_2wri = pickle.load(handle)
with open(path4+'SSPicker_'+version+'_4c_'+lambda_4c+'_target_spec_rec3.pickle', 'rb') as handle:
    rec3_hydra_2wri = pickle.load(handle)


fig = p.figure()
ax = fig.gca()
ax.set_autoscale_on(False)
ax.plot(rec2_cryolo_2wri, prec2_cryolo_2wri, label='crYOLO')
# ax.plot(rec2_boxnet_2wri, prec2_boxnet_2wri, label='Boxnet')
ax.plot(rec2_boxnet_masked_2wri, prec2_boxnet_masked_2wri, label='Boxnet_masked')
# ax.plot(rec2_7_models_2wri, prec2_7_models_2wri, label='7 models')
ax.plot(rec2_hydra_2wri, prec2_hydra_2wri, label='HydraPicker')
ax.axis([0,1,0,1])
ax.set(xlabel='Recall', ylabel='Precision')
ax.grid()
ax.legend()

fig = p.figure()
ax = fig.gca()
ax.set_autoscale_on(False)
ax.plot(fpr2_cryolo_2wri, rec3_cryolo_2wri, label='crYOLO')
# ax.plot(fpr2_boxnet_2wri, rec3_boxnet_2wri, label='Boxnet')
ax.plot(fpr2_boxnet_masked_2wri, rec3_boxnet_masked_2wri, label='Boxnet_masked')
# ax.plot(fpr2_7_models_2wri, rec3_7_models_2wri, label='7 models')
ax.plot(fpr2_hydra_2wri, rec3_hydra_2wri, label='HydraPicker')
ax.axis([0,1,0,1])
ax.set(xlabel='False-Positive Rate', ylabel='Recall')
ax.grid()
ax.legend()

# %% [markdown]
# # 5VY5

# %%
version = "29_6"

lambda_4c = "1001.3"
with open(path4+'SSPicker_'+version+'_4c_'+lambda_4c+'_target_gen_rec2.pickle', 'rb') as handle:
    rec2_cryolo_2wri = pickle.load(handle)
with open(path4+'SSPicker_'+version+'_4c_'+lambda_4c+'_target_gen_prec2.pickle', 'rb') as handle:
    prec2_cryolo_2wri = pickle.load(handle)
with open(path4+'SSPicker_'+version+'_4c_'+lambda_4c+'_target_gen_fpr2.pickle', 'rb') as handle:
    fpr2_cryolo_2wri = pickle.load(handle)
with open(path4+'SSPicker_'+version+'_4c_'+lambda_4c+'_target_gen_rec3.pickle', 'rb') as handle:
    rec3_cryolo_2wri = pickle.load(handle) 

# lambda_4c = "1002.3"
# with open(path4+'SSPicker_'+version+'_4c_'+lambda_4c+'_target_gen_rec2.pickle', 'rb') as handle:
#     rec2_boxnet_2wri = pickle.load(handle)
# with open(path4+'SSPicker_'+version+'_4c_'+lambda_4c+'_target_gen_prec2.pickle', 'rb') as handle:
#     prec2_boxnet_2wri = pickle.load(handle)
# with open(path4+'SSPicker_'+version+'_4c_'+lambda_4c+'_target_gen_fpr2.pickle', 'rb') as handle:
#     fpr2_boxnet_2wri = pickle.load(handle)
# with open(path4+'SSPicker_'+version+'_4c_'+lambda_4c+'_target_gen_rec3.pickle', 'rb') as handle:
#     rec3_boxnet_2wri = pickle.load(handle)
    
lambda_4c = "1003.3"
with open(path4+'SSPicker_'+version+'_4c_'+lambda_4c+'_target_gen_rec2.pickle', 'rb') as handle:
    rec2_boxnet_masked_2wri = pickle.load(handle)
with open(path4+'SSPicker_'+version+'_4c_'+lambda_4c+'_target_gen_prec2.pickle', 'rb') as handle:
    prec2_boxnet_masked_2wri = pickle.load(handle)
with open(path4+'SSPicker_'+version+'_4c_'+lambda_4c+'_target_gen_fpr2.pickle', 'rb') as handle:
    fpr2_boxnet_masked_2wri = pickle.load(handle)
with open(path4+'SSPicker_'+version+'_4c_'+lambda_4c+'_target_gen_rec3.pickle', 'rb') as handle:
    rec3_boxnet_masked_2wri = pickle.load(handle) 

# lambda_4c = "1004.3"
# with open(path4+'SSPicker_'+version+'_4c_'+lambda_4c+'_target_gen_rec2.pickle', 'rb') as handle:
#     rec2_7_models_2wri = pickle.load(handle)
# with open(path4+'SSPicker_'+version+'_4c_'+lambda_4c+'_target_gen_prec2.pickle', 'rb') as handle:
#     prec2_7_models_2wri = pickle.load(handle)
# with open(path4+'SSPicker_'+version+'_4c_'+lambda_4c+'_target_gen_fpr2.pickle', 'rb') as handle:
#     fpr2_7_models_2wri = pickle.load(handle)
# with open(path4+'SSPicker_'+version+'_4c_'+lambda_4c+'_target_gen_rec3.pickle', 'rb') as handle:
#     rec3_7_models_2wri = pickle.load(handle) 
    
lambda_4c = "1005.3"
with open(path4+'SSPicker_'+version+'_4c_'+lambda_4c+'_target_spec_rec2.pickle', 'rb') as handle:
    rec2_hydra_2wri = pickle.load(handle)
with open(path4+'SSPicker_'+version+'_4c_'+lambda_4c+'_target_spec_prec2.pickle', 'rb') as handle:
    prec2_hydra_2wri = pickle.load(handle)
with open(path4+'SSPicker_'+version+'_4c_'+lambda_4c+'_target_spec_fpr2.pickle', 'rb') as handle:
    fpr2_hydra_2wri = pickle.load(handle)
with open(path4+'SSPicker_'+version+'_4c_'+lambda_4c+'_target_spec_rec3.pickle', 'rb') as handle:
    rec3_hydra_2wri = pickle.load(handle)


fig = p.figure()
ax = fig.gca()
ax.set_autoscale_on(False)
ax.plot(rec2_cryolo_2wri, prec2_cryolo_2wri, label='crYOLO')
# ax.plot(rec2_boxnet_2wri, prec2_boxnet_2wri, label='Boxnet')
ax.plot(rec2_boxnet_masked_2wri, prec2_boxnet_masked_2wri, label='Boxnet_masked')
# ax.plot(rec2_7_models_2wri, prec2_7_models_2wri, label='7 models')
ax.plot(rec2_hydra_2wri, prec2_hydra_2wri, label='HydraPicker')
ax.axis([0,1,0,1])
ax.set(xlabel='Recall', ylabel='Precision')
ax.grid()
ax.legend()

fig = p.figure()
ax = fig.gca()
ax.set_autoscale_on(False)
ax.plot(fpr2_cryolo_2wri, rec3_cryolo_2wri, label='crYOLO')
# ax.plot(fpr2_boxnet_2wri, rec3_boxnet_2wri, label='Boxnet')
ax.plot(fpr2_boxnet_masked_2wri, rec3_boxnet_masked_2wri, label='Boxnet_masked')
# ax.plot(fpr2_7_models_2wri, rec3_7_models_2wri, label='7 models')
ax.plot(fpr2_hydra_2wri, rec3_hydra_2wri, label='HydraPicker')
ax.axis([0,1,0,1])
ax.set(xlabel='False-Positive Rate', ylabel='Recall')
ax.grid()
ax.legend()

# %% [markdown]
# # 5W3L

# %%
version = "29_6"

lambda_4c = "1001.4"
with open(path4+'SSPicker_'+version+'_4c_'+lambda_4c+'_target_gen_rec2.pickle', 'rb') as handle:
    rec2_cryolo_2wri = pickle.load(handle)
with open(path4+'SSPicker_'+version+'_4c_'+lambda_4c+'_target_gen_prec2.pickle', 'rb') as handle:
    prec2_cryolo_2wri = pickle.load(handle)
with open(path4+'SSPicker_'+version+'_4c_'+lambda_4c+'_target_gen_fpr2.pickle', 'rb') as handle:
    fpr2_cryolo_2wri = pickle.load(handle)
with open(path4+'SSPicker_'+version+'_4c_'+lambda_4c+'_target_gen_rec3.pickle', 'rb') as handle:
    rec3_cryolo_2wri = pickle.load(handle) 

# lambda_4c = "1002.4"
# with open(path4+'SSPicker_'+version+'_4c_'+lambda_4c+'_target_gen_rec2.pickle', 'rb') as handle:
#     rec2_boxnet_2wri = pickle.load(handle)
# with open(path4+'SSPicker_'+version+'_4c_'+lambda_4c+'_target_gen_prec2.pickle', 'rb') as handle:
#     prec2_boxnet_2wri = pickle.load(handle)
# with open(path4+'SSPicker_'+version+'_4c_'+lambda_4c+'_target_gen_fpr2.pickle', 'rb') as handle:
#     fpr2_boxnet_2wri = pickle.load(handle)
# with open(path4+'SSPicker_'+version+'_4c_'+lambda_4c+'_target_gen_rec3.pickle', 'rb') as handle:
#     rec3_boxnet_2wri = pickle.load(handle)
    
lambda_4c = "1003.4"
with open(path4+'SSPicker_'+version+'_4c_'+lambda_4c+'_target_gen_rec2.pickle', 'rb') as handle:
    rec2_boxnet_masked_2wri = pickle.load(handle)
with open(path4+'SSPicker_'+version+'_4c_'+lambda_4c+'_target_gen_prec2.pickle', 'rb') as handle:
    prec2_boxnet_masked_2wri = pickle.load(handle)
with open(path4+'SSPicker_'+version+'_4c_'+lambda_4c+'_target_gen_fpr2.pickle', 'rb') as handle:
    fpr2_boxnet_masked_2wri = pickle.load(handle)
with open(path4+'SSPicker_'+version+'_4c_'+lambda_4c+'_target_gen_rec3.pickle', 'rb') as handle:
    rec3_boxnet_masked_2wri = pickle.load(handle) 

# lambda_4c = "1004.4"
# with open(path4+'SSPicker_'+version+'_4c_'+lambda_4c+'_target_gen_rec2.pickle', 'rb') as handle:
#     rec2_7_models_2wri = pickle.load(handle)
# with open(path4+'SSPicker_'+version+'_4c_'+lambda_4c+'_target_gen_prec2.pickle', 'rb') as handle:
#     prec2_7_models_2wri = pickle.load(handle)
# with open(path4+'SSPicker_'+version+'_4c_'+lambda_4c+'_target_gen_fpr2.pickle', 'rb') as handle:
#     fpr2_7_models_2wri = pickle.load(handle)
# with open(path4+'SSPicker_'+version+'_4c_'+lambda_4c+'_target_gen_rec3.pickle', 'rb') as handle:
#     rec3_7_models_2wri = pickle.load(handle) 
    
lambda_4c = "1005.4"
with open(path4+'SSPicker_'+version+'_4c_'+lambda_4c+'_target_spec_rec2.pickle', 'rb') as handle:
    rec2_hydra_2wri = pickle.load(handle)
with open(path4+'SSPicker_'+version+'_4c_'+lambda_4c+'_target_spec_prec2.pickle', 'rb') as handle:
    prec2_hydra_2wri = pickle.load(handle)
with open(path4+'SSPicker_'+version+'_4c_'+lambda_4c+'_target_spec_fpr2.pickle', 'rb') as handle:
    fpr2_hydra_2wri = pickle.load(handle)
with open(path4+'SSPicker_'+version+'_4c_'+lambda_4c+'_target_spec_rec3.pickle', 'rb') as handle:
    rec3_hydra_2wri = pickle.load(handle)


fig = p.figure()
ax = fig.gca()
ax.set_autoscale_on(False)
ax.plot(rec2_cryolo_2wri, prec2_cryolo_2wri, label='crYOLO')
# ax.plot(rec2_boxnet_2wri, prec2_boxnet_2wri, label='Boxnet')
ax.plot(rec2_boxnet_masked_2wri, prec2_boxnet_masked_2wri, label='Boxnet_masked')
# ax.plot(rec2_7_models_2wri, prec2_7_models_2wri, label='7 models')
ax.plot(rec2_hydra_2wri, prec2_hydra_2wri, label='HydraPicker')
ax.axis([0,1,0,1])
ax.set(xlabel='Recall', ylabel='Precision')
ax.grid()
ax.legend()

fig = p.figure()
ax = fig.gca()
ax.set_autoscale_on(False)
ax.plot(fpr2_cryolo_2wri, rec3_cryolo_2wri, label='crYOLO')
# ax.plot(fpr2_boxnet_2wri, rec3_boxnet_2wri, label='Boxnet')
ax.plot(fpr2_boxnet_masked_2wri, rec3_boxnet_masked_2wri, label='Boxnet_masked')
# ax.plot(fpr2_7_models_2wri, rec3_7_models_2wri, label='7 models')
ax.plot(fpr2_hydra_2wri, rec3_hydra_2wri, label='HydraPicker')
ax.axis([0,1,0,1])
ax.set(xlabel='False-Positive Rate', ylabel='Recall')
ax.grid()
ax.legend()

# %% [markdown]
# # 5XNL

# %%
version = "29_6"

lambda_4c = "1001.5"
with open(path4+'SSPicker_'+version+'_4c_'+lambda_4c+'_target_gen_rec2.pickle', 'rb') as handle:
    rec2_cryolo_2wri = pickle.load(handle)
with open(path4+'SSPicker_'+version+'_4c_'+lambda_4c+'_target_gen_prec2.pickle', 'rb') as handle:
    prec2_cryolo_2wri = pickle.load(handle)
with open(path4+'SSPicker_'+version+'_4c_'+lambda_4c+'_target_gen_fpr2.pickle', 'rb') as handle:
    fpr2_cryolo_2wri = pickle.load(handle)
with open(path4+'SSPicker_'+version+'_4c_'+lambda_4c+'_target_gen_rec3.pickle', 'rb') as handle:
    rec3_cryolo_2wri = pickle.load(handle) 

# lambda_4c = "1002.5"
# with open(path4+'SSPicker_'+version+'_4c_'+lambda_4c+'_target_gen_rec2.pickle', 'rb') as handle:
#     rec2_boxnet_2wri = pickle.load(handle)
# with open(path4+'SSPicker_'+version+'_4c_'+lambda_4c+'_target_gen_prec2.pickle', 'rb') as handle:
#     prec2_boxnet_2wri = pickle.load(handle)
# with open(path4+'SSPicker_'+version+'_4c_'+lambda_4c+'_target_gen_fpr2.pickle', 'rb') as handle:
#     fpr2_boxnet_2wri = pickle.load(handle)
# with open(path4+'SSPicker_'+version+'_4c_'+lambda_4c+'_target_gen_rec3.pickle', 'rb') as handle:
#     rec3_boxnet_2wri = pickle.load(handle)
    
lambda_4c = "1003.5"
with open(path4+'SSPicker_'+version+'_4c_'+lambda_4c+'_target_gen_rec2.pickle', 'rb') as handle:
    rec2_boxnet_masked_2wri = pickle.load(handle)
with open(path4+'SSPicker_'+version+'_4c_'+lambda_4c+'_target_gen_prec2.pickle', 'rb') as handle:
    prec2_boxnet_masked_2wri = pickle.load(handle)
with open(path4+'SSPicker_'+version+'_4c_'+lambda_4c+'_target_gen_fpr2.pickle', 'rb') as handle:
    fpr2_boxnet_masked_2wri = pickle.load(handle)
with open(path4+'SSPicker_'+version+'_4c_'+lambda_4c+'_target_gen_rec3.pickle', 'rb') as handle:
    rec3_boxnet_masked_2wri = pickle.load(handle) 

# lambda_4c = "1004.5"
# with open(path4+'SSPicker_'+version+'_4c_'+lambda_4c+'_target_gen_rec2.pickle', 'rb') as handle:
#     rec2_7_models_2wri = pickle.load(handle)
# with open(path4+'SSPicker_'+version+'_4c_'+lambda_4c+'_target_gen_prec2.pickle', 'rb') as handle:
#     prec2_7_models_2wri = pickle.load(handle)
# with open(path4+'SSPicker_'+version+'_4c_'+lambda_4c+'_target_gen_fpr2.pickle', 'rb') as handle:
#     fpr2_7_models_2wri = pickle.load(handle)
# with open(path4+'SSPicker_'+version+'_4c_'+lambda_4c+'_target_gen_rec3.pickle', 'rb') as handle:
#     rec3_7_models_2wri = pickle.load(handle) 
    
lambda_4c = "1005.5"
with open(path4+'SSPicker_'+version+'_4c_'+lambda_4c+'_target_spec_rec2.pickle', 'rb') as handle:
    rec2_hydra_2wri = pickle.load(handle)
with open(path4+'SSPicker_'+version+'_4c_'+lambda_4c+'_target_spec_prec2.pickle', 'rb') as handle:
    prec2_hydra_2wri = pickle.load(handle)
with open(path4+'SSPicker_'+version+'_4c_'+lambda_4c+'_target_spec_fpr2.pickle', 'rb') as handle:
    fpr2_hydra_2wri = pickle.load(handle)
with open(path4+'SSPicker_'+version+'_4c_'+lambda_4c+'_target_spec_rec3.pickle', 'rb') as handle:
    rec3_hydra_2wri = pickle.load(handle)


fig = p.figure()
ax = fig.gca()
ax.set_autoscale_on(False)
ax.plot(rec2_cryolo_2wri, prec2_cryolo_2wri, label='crYOLO')
# ax.plot(rec2_boxnet_2wri, prec2_boxnet_2wri, label='Boxnet')
ax.plot(rec2_boxnet_masked_2wri, prec2_boxnet_masked_2wri, label='Boxnet_masked')
# ax.plot(rec2_7_models_2wri, prec2_7_models_2wri, label='7 models')
ax.plot(rec2_hydra_2wri, prec2_hydra_2wri, label='HydraPicker')
ax.axis([0,1,0,1])
ax.set(xlabel='Recall', ylabel='Precision')
ax.grid()
ax.legend()

fig = p.figure()
ax = fig.gca()
ax.set_autoscale_on(False)
ax.plot(fpr2_cryolo_2wri, rec3_cryolo_2wri, label='crYOLO')
# ax.plot(fpr2_boxnet_2wri, rec3_boxnet_2wri, label='Boxnet')
ax.plot(fpr2_boxnet_masked_2wri, rec3_boxnet_masked_2wri, label='Boxnet_masked')
# ax.plot(fpr2_7_models_2wri, rec3_7_models_2wri, label='7 models')
ax.plot(fpr2_hydra_2wri, rec3_hydra_2wri, label='HydraPicker')
ax.axis([0,1,0,1])
ax.set(xlabel='False-Positive Rate', ylabel='Recall')
ax.grid()
ax.legend()

# %% [markdown]
# # 6B7N

# %%
version = "29_6"

lambda_4c = "1001.6"
with open(path4+'SSPicker_'+version+'_4c_'+lambda_4c+'_target_gen_rec2.pickle', 'rb') as handle:
    rec2_cryolo_2wri = pickle.load(handle)
with open(path4+'SSPicker_'+version+'_4c_'+lambda_4c+'_target_gen_prec2.pickle', 'rb') as handle:
    prec2_cryolo_2wri = pickle.load(handle)
with open(path4+'SSPicker_'+version+'_4c_'+lambda_4c+'_target_gen_fpr2.pickle', 'rb') as handle:
    fpr2_cryolo_2wri = pickle.load(handle)
with open(path4+'SSPicker_'+version+'_4c_'+lambda_4c+'_target_gen_rec3.pickle', 'rb') as handle:
    rec3_cryolo_2wri = pickle.load(handle) 

# lambda_4c = "1002.6"
# with open(path4+'SSPicker_'+version+'_4c_'+lambda_4c+'_target_gen_rec2.pickle', 'rb') as handle:
#     rec2_boxnet_2wri = pickle.load(handle)
# with open(path4+'SSPicker_'+version+'_4c_'+lambda_4c+'_target_gen_prec2.pickle', 'rb') as handle:
#     prec2_boxnet_2wri = pickle.load(handle)
# with open(path4+'SSPicker_'+version+'_4c_'+lambda_4c+'_target_gen_fpr2.pickle', 'rb') as handle:
#     fpr2_boxnet_2wri = pickle.load(handle)
# with open(path4+'SSPicker_'+version+'_4c_'+lambda_4c+'_target_gen_rec3.pickle', 'rb') as handle:
#     rec3_boxnet_2wri = pickle.load(handle)
    
lambda_4c = "1003.6"
with open(path4+'SSPicker_'+version+'_4c_'+lambda_4c+'_target_gen_rec2.pickle', 'rb') as handle:
    rec2_boxnet_masked_2wri = pickle.load(handle)
with open(path4+'SSPicker_'+version+'_4c_'+lambda_4c+'_target_gen_prec2.pickle', 'rb') as handle:
    prec2_boxnet_masked_2wri = pickle.load(handle)
with open(path4+'SSPicker_'+version+'_4c_'+lambda_4c+'_target_gen_fpr2.pickle', 'rb') as handle:
    fpr2_boxnet_masked_2wri = pickle.load(handle)
with open(path4+'SSPicker_'+version+'_4c_'+lambda_4c+'_target_gen_rec3.pickle', 'rb') as handle:
    rec3_boxnet_masked_2wri = pickle.load(handle) 

# lambda_4c = "1004.6"
# with open(path4+'SSPicker_'+version+'_4c_'+lambda_4c+'_target_gen_rec2.pickle', 'rb') as handle:
#     rec2_7_models_2wri = pickle.load(handle)
# with open(path4+'SSPicker_'+version+'_4c_'+lambda_4c+'_target_gen_prec2.pickle', 'rb') as handle:
#     prec2_7_models_2wri = pickle.load(handle)
# with open(path4+'SSPicker_'+version+'_4c_'+lambda_4c+'_target_gen_fpr2.pickle', 'rb') as handle:
#     fpr2_7_models_2wri = pickle.load(handle)
# with open(path4+'SSPicker_'+version+'_4c_'+lambda_4c+'_target_gen_rec3.pickle', 'rb') as handle:
#     rec3_7_models_2wri = pickle.load(handle) 
    
lambda_4c = "1005.6"
with open(path4+'SSPicker_'+version+'_4c_'+lambda_4c+'_target_spec_rec2.pickle', 'rb') as handle:
    rec2_hydra_2wri = pickle.load(handle)
with open(path4+'SSPicker_'+version+'_4c_'+lambda_4c+'_target_spec_prec2.pickle', 'rb') as handle:
    prec2_hydra_2wri = pickle.load(handle)
with open(path4+'SSPicker_'+version+'_4c_'+lambda_4c+'_target_spec_fpr2.pickle', 'rb') as handle:
    fpr2_hydra_2wri = pickle.load(handle)
with open(path4+'SSPicker_'+version+'_4c_'+lambda_4c+'_target_spec_rec3.pickle', 'rb') as handle:
    rec3_hydra_2wri = pickle.load(handle)


fig = p.figure()
ax = fig.gca()
ax.set_autoscale_on(False)
ax.plot(rec2_cryolo_2wri, prec2_cryolo_2wri, label='crYOLO')
# ax.plot(rec2_boxnet_2wri, prec2_boxnet_2wri, label='Boxnet')
ax.plot(rec2_boxnet_masked_2wri, prec2_boxnet_masked_2wri, label='Boxnet_masked')
# ax.plot(rec2_7_models_2wri, prec2_7_models_2wri, label='7 models')
ax.plot(rec2_hydra_2wri, prec2_hydra_2wri, label='HydraPicker')
ax.axis([0,1,0,1])
ax.set(xlabel='Recall', ylabel='Precision')
ax.grid()
ax.legend()

fig = p.figure()
ax = fig.gca()
ax.set_autoscale_on(False)
ax.plot(fpr2_cryolo_2wri, rec3_cryolo_2wri, label='crYOLO')
# ax.plot(fpr2_boxnet_2wri, rec3_boxnet_2wri, label='Boxnet')
ax.plot(fpr2_boxnet_masked_2wri, rec3_boxnet_masked_2wri, label='Boxnet_masked')
# ax.plot(fpr2_7_models_2wri, rec3_7_models_2wri, label='7 models')
ax.plot(fpr2_hydra_2wri, rec3_hydra_2wri, label='HydraPicker')
ax.axis([0,1,0,1])
ax.set(xlabel='False-Positive Rate', ylabel='Recall')
ax.grid()
ax.legend()

# %% [markdown]
# # 6B44

# %%
version = "29_6"

lambda_4c = "1001.7"
with open(path4+'SSPicker_'+version+'_4c_'+lambda_4c+'_target_gen_rec2.pickle', 'rb') as handle:
    rec2_cryolo_2wri = pickle.load(handle)
with open(path4+'SSPicker_'+version+'_4c_'+lambda_4c+'_target_gen_prec2.pickle', 'rb') as handle:
    prec2_cryolo_2wri = pickle.load(handle)
with open(path4+'SSPicker_'+version+'_4c_'+lambda_4c+'_target_gen_fpr2.pickle', 'rb') as handle:
    fpr2_cryolo_2wri = pickle.load(handle)
with open(path4+'SSPicker_'+version+'_4c_'+lambda_4c+'_target_gen_rec3.pickle', 'rb') as handle:
    rec3_cryolo_2wri = pickle.load(handle) 

# lambda_4c = "1002.7"
# with open(path4+'SSPicker_'+version+'_4c_'+lambda_4c+'_target_gen_rec2.pickle', 'rb') as handle:
#     rec2_boxnet_2wri = pickle.load(handle)
# with open(path4+'SSPicker_'+version+'_4c_'+lambda_4c+'_target_gen_prec2.pickle', 'rb') as handle:
#     prec2_boxnet_2wri = pickle.load(handle)
# with open(path4+'SSPicker_'+version+'_4c_'+lambda_4c+'_target_gen_fpr2.pickle', 'rb') as handle:
#     fpr2_boxnet_2wri = pickle.load(handle)
# with open(path4+'SSPicker_'+version+'_4c_'+lambda_4c+'_target_gen_rec3.pickle', 'rb') as handle:
#     rec3_boxnet_2wri = pickle.load(handle)
    
lambda_4c = "1003.7"
with open(path4+'SSPicker_'+version+'_4c_'+lambda_4c+'_target_gen_rec2.pickle', 'rb') as handle:
    rec2_boxnet_masked_2wri = pickle.load(handle)
with open(path4+'SSPicker_'+version+'_4c_'+lambda_4c+'_target_gen_prec2.pickle', 'rb') as handle:
    prec2_boxnet_masked_2wri = pickle.load(handle)
with open(path4+'SSPicker_'+version+'_4c_'+lambda_4c+'_target_gen_fpr2.pickle', 'rb') as handle:
    fpr2_boxnet_masked_2wri = pickle.load(handle)
with open(path4+'SSPicker_'+version+'_4c_'+lambda_4c+'_target_gen_rec3.pickle', 'rb') as handle:
    rec3_boxnet_masked_2wri = pickle.load(handle) 

# lambda_4c = "1004.7"
# with open(path4+'SSPicker_'+version+'_4c_'+lambda_4c+'_target_gen_rec2.pickle', 'rb') as handle:
#     rec2_7_models_2wri = pickle.load(handle)
# with open(path4+'SSPicker_'+version+'_4c_'+lambda_4c+'_target_gen_prec2.pickle', 'rb') as handle:
#     prec2_7_models_2wri = pickle.load(handle)
# with open(path4+'SSPicker_'+version+'_4c_'+lambda_4c+'_target_gen_fpr2.pickle', 'rb') as handle:
#     fpr2_7_models_2wri = pickle.load(handle)
# with open(path4+'SSPicker_'+version+'_4c_'+lambda_4c+'_target_gen_rec3.pickle', 'rb') as handle:
#     rec3_7_models_2wri = pickle.load(handle) 
    
lambda_4c = "1005.7"
with open(path4+'SSPicker_'+version+'_4c_'+lambda_4c+'_source_spec_rec2.pickle', 'rb') as handle:
    rec2_hydra_2wri = pickle.load(handle)
with open(path4+'SSPicker_'+version+'_4c_'+lambda_4c+'_source_spec_prec2.pickle', 'rb') as handle:
    prec2_hydra_2wri = pickle.load(handle)
with open(path4+'SSPicker_'+version+'_4c_'+lambda_4c+'_source_spec_fpr2.pickle', 'rb') as handle:
    fpr2_hydra_2wri = pickle.load(handle)
with open(path4+'SSPicker_'+version+'_4c_'+lambda_4c+'_source_spec_rec3.pickle', 'rb') as handle:
    rec3_hydra_2wri = pickle.load(handle)


fig = p.figure()
ax = fig.gca()
ax.set_autoscale_on(False)
ax.plot(rec2_cryolo_2wri, prec2_cryolo_2wri, label='crYOLO')
# ax.plot(rec2_boxnet_2wri, prec2_boxnet_2wri, label='Boxnet')
ax.plot(rec2_boxnet_masked_2wri, prec2_boxnet_masked_2wri, label='Boxnet_masked')
# ax.plot(rec2_7_models_2wri, prec2_7_models_2wri, label='7 models')
ax.plot(rec2_hydra_2wri, prec2_hydra_2wri, label='HydraPicker')
ax.axis([0,1,0,1])
ax.set(xlabel='Recall', ylabel='Precision')
ax.grid()
ax.legend()

fig = p.figure()
ax = fig.gca()
ax.set_autoscale_on(False)
ax.plot(fpr2_cryolo_2wri, rec3_cryolo_2wri, label='crYOLO')
# ax.plot(fpr2_boxnet_2wri, rec3_boxnet_2wri, label='Boxnet')
ax.plot(fpr2_boxnet_masked_2wri, rec3_boxnet_masked_2wri, label='Boxnet_masked')
# ax.plot(fpr2_7_models_2wri, rec3_7_models_2wri, label='7 models')
ax.plot(fpr2_hydra_2wri, rec3_hydra_2wri, label='HydraPicker')
ax.axis([0,1,0,1])
ax.set(xlabel='False-Positive Rate', ylabel='Recall')
ax.grid()
ax.legend()

# %% [markdown]
# # threshold test

# %%
version = "29_6"

# lambda_4c = "10000.0"
# with open(path4+'SSPicker_'+version+'_4c_'+lambda_4c+'_target_gen_rec2.pickle', 'rb') as handle:
#     rec2_cryolo_2wri = pickle.load(handle)
# with open(path4+'SSPicker_'+version+'_4c_'+lambda_4c+'_target_gen_prec2.pickle', 'rb') as handle:
#     prec2_cryolo_2wri = pickle.load(handle)
# with open(path4+'SSPicker_'+version+'_4c_'+lambda_4c+'_target_gen_fpr2.pickle', 'rb') as handle:
#     fpr2_cryolo_2wri = pickle.load(handle)
# with open(path4+'SSPicker_'+version+'_4c_'+lambda_4c+'_target_gen_rec3.pickle', 'rb') as handle:
#     rec3_cryolo_2wri = pickle.load(handle) 

# lambda_4c = "1002.7"
# with open(path4+'SSPicker_'+version+'_4c_'+lambda_4c+'_target_gen_rec2.pickle', 'rb') as handle:
#     rec2_boxnet_2wri = pickle.load(handle)
# with open(path4+'SSPicker_'+version+'_4c_'+lambda_4c+'_target_gen_prec2.pickle', 'rb') as handle:
#     prec2_boxnet_2wri = pickle.load(handle)
# with open(path4+'SSPicker_'+version+'_4c_'+lambda_4c+'_target_gen_fpr2.pickle', 'rb') as handle:
#     fpr2_boxnet_2wri = pickle.load(handle)
# with open(path4+'SSPicker_'+version+'_4c_'+lambda_4c+'_target_gen_rec3.pickle', 'rb') as handle:
#     rec3_boxnet_2wri = pickle.load(handle)
    
# lambda_4c = "1003.7"
# with open(path4+'SSPicker_'+version+'_4c_'+lambda_4c+'_target_gen_rec2.pickle', 'rb') as handle:
#     rec2_boxnet_masked_2wri = pickle.load(handle)
# with open(path4+'SSPicker_'+version+'_4c_'+lambda_4c+'_target_gen_prec2.pickle', 'rb') as handle:
#     prec2_boxnet_masked_2wri = pickle.load(handle)
# with open(path4+'SSPicker_'+version+'_4c_'+lambda_4c+'_target_gen_fpr2.pickle', 'rb') as handle:
#     fpr2_boxnet_masked_2wri = pickle.load(handle)
# with open(path4+'SSPicker_'+version+'_4c_'+lambda_4c+'_target_gen_rec3.pickle', 'rb') as handle:
#     rec3_boxnet_masked_2wri = pickle.load(handle) 

# lambda_4c = "1004.7"
# with open(path4+'SSPicker_'+version+'_4c_'+lambda_4c+'_target_gen_rec2.pickle', 'rb') as handle:
#     rec2_7_models_2wri = pickle.load(handle)
# with open(path4+'SSPicker_'+version+'_4c_'+lambda_4c+'_target_gen_prec2.pickle', 'rb') as handle:
#     prec2_7_models_2wri = pickle.load(handle)
# with open(path4+'SSPicker_'+version+'_4c_'+lambda_4c+'_target_gen_fpr2.pickle', 'rb') as handle:
#     fpr2_7_models_2wri = pickle.load(handle)
# with open(path4+'SSPicker_'+version+'_4c_'+lambda_4c+'_target_gen_rec3.pickle', 'rb') as handle:
#     rec3_7_models_2wri = pickle.load(handle) 
    
# lambda_4c = "10000.0"
# with open(path4+'SSPicker_'+version+'_4c_'+lambda_4c+'_target_spec_rec2.pickle', 'rb') as handle:
#     rec2_hydra_2wri = pickle.load(handle)
# with open(path4+'SSPicker_'+version+'_4c_'+lambda_4c+'_target_spec_prec2.pickle', 'rb') as handle:
#     prec2_hydra_2wri = pickle.load(handle)
# with open(path4+'SSPicker_'+version+'_4c_'+lambda_4c+'_target_spec_fpr2.pickle', 'rb') as handle:
#     fpr2_hydra_2wri = pickle.load(handle)
# with open(path4+'SSPicker_'+version+'_4c_'+lambda_4c+'_target_spec_rec3.pickle', 'rb') as handle:
#     rec3_hydra_2wri = pickle.load(handle)
    
lambda_4b = "11111.0"
with open(path4+'SSPicker_'+version+'_4b_'+lambda_4b+'_target_gen_rec2.pickle', 'rb') as handle:
    rec2_hydra = pickle.load(handle)
with open(path4+'SSPicker_'+version+'_4b_'+lambda_4b+'_target_gen_prec2.pickle', 'rb') as handle:
    prec2_hydra = pickle.load(handle)
with open(path4+'SSPicker_'+version+'_4b_'+lambda_4b+'_target_gen_fpr2.pickle', 'rb') as handle:
    fpr2_hydra = pickle.load(handle)
with open(path4+'SSPicker_'+version+'_4b_'+lambda_4b+'_target_gen_rec3.pickle', 'rb') as handle:
    rec3_hydra = pickle.load(handle)
    
lambda_4c = "11111.0"
with open(path4+'SSPicker_'+version+'_4c_'+lambda_4c+'_target_spec_rec2.pickle', 'rb') as handle:
    rec2_hydra_4c = pickle.load(handle)
with open(path4+'SSPicker_'+version+'_4c_'+lambda_4c+'_target_spec_prec2.pickle', 'rb') as handle:
    prec2_hydra_4c = pickle.load(handle)
with open(path4+'SSPicker_'+version+'_4c_'+lambda_4c+'_target_spec_fpr2.pickle', 'rb') as handle:
    fpr2_hydra_4c = pickle.load(handle)
with open(path4+'SSPicker_'+version+'_4c_'+lambda_4c+'_target_spec_rec3.pickle', 'rb') as handle:
    rec3_hydra_4c = pickle.load(handle)
    
lambda_4b = "11112.0"
with open(path4+'SSPicker_'+version+'_4b_'+lambda_4b+'_target_gen_rec2.pickle', 'rb') as handle:
    rec2_boxnet_unmasked_sources = pickle.load(handle)
with open(path4+'SSPicker_'+version+'_4b_'+lambda_4b+'_target_gen_prec2.pickle', 'rb') as handle:
    prec2_boxnet_unmasked_sources = pickle.load(handle)
with open(path4+'SSPicker_'+version+'_4b_'+lambda_4b+'_target_gen_fpr2.pickle', 'rb') as handle:
    fpr2_boxnet_unmasked_sources = pickle.load(handle)
with open(path4+'SSPicker_'+version+'_4b_'+lambda_4b+'_target_gen_rec3.pickle', 'rb') as handle:
    rec3_boxnet_unmasked_sources = pickle.load(handle)

lambda_4b = "11113.0"
with open(path4+'SSPicker_'+version+'_4b_'+lambda_4b+'_target_gen_rec2.pickle', 'rb') as handle:
    rec2_boxnet_masked_sources = pickle.load(handle)
with open(path4+'SSPicker_'+version+'_4b_'+lambda_4b+'_target_gen_prec2.pickle', 'rb') as handle:
    prec2_boxnet_masked_sources = pickle.load(handle)
with open(path4+'SSPicker_'+version+'_4b_'+lambda_4b+'_target_gen_fpr2.pickle', 'rb') as handle:
    fpr2_boxnet_masked_sources = pickle.load(handle)
with open(path4+'SSPicker_'+version+'_4b_'+lambda_4b+'_target_gen_rec3.pickle', 'rb') as handle:
    rec3_boxnet_masked_sources = pickle.load(handle)

lambda_4c = "11112.0"
with open(path4+'SSPicker_'+version+'_4c_'+lambda_4c+'_target_gen_rec2.pickle', 'rb') as handle:
    rec2_boxnet_unmasked_targets = pickle.load(handle)
with open(path4+'SSPicker_'+version+'_4c_'+lambda_4c+'_target_gen_prec2.pickle', 'rb') as handle:
    prec2_boxnet_unmasked_targets = pickle.load(handle)
with open(path4+'SSPicker_'+version+'_4c_'+lambda_4c+'_target_gen_fpr2.pickle', 'rb') as handle:
    fpr2_boxnet_unmasked_targets = pickle.load(handle)
with open(path4+'SSPicker_'+version+'_4c_'+lambda_4c+'_target_gen_rec3.pickle', 'rb') as handle:
    rec3_boxnet_unmasked_targets = pickle.load(handle)

lambda_4c = "11113.0"
with open(path4+'SSPicker_'+version+'_4c_'+lambda_4c+'_target_gen_rec2.pickle', 'rb') as handle:
    rec2_boxnet_masked_targets = pickle.load(handle)
with open(path4+'SSPicker_'+version+'_4c_'+lambda_4c+'_target_gen_prec2.pickle', 'rb') as handle:
    prec2_boxnet_masked_targets = pickle.load(handle)
with open(path4+'SSPicker_'+version+'_4c_'+lambda_4c+'_target_gen_fpr2.pickle', 'rb') as handle:
    fpr2_boxnet_masked_targets = pickle.load(handle)
with open(path4+'SSPicker_'+version+'_4c_'+lambda_4c+'_target_gen_rec3.pickle', 'rb') as handle:
    rec3_boxnet_masked_targets = pickle.load(handle)

lambda_4b = "11114.0"
with open(path4+'SSPicker_'+version+'_4b_'+lambda_4b+'_target_gen_rec2.pickle', 'rb') as handle:
    rec2_cryolo_sources = pickle.load(handle)
with open(path4+'SSPicker_'+version+'_4b_'+lambda_4b+'_target_gen_prec2.pickle', 'rb') as handle:
    prec2_cryolo_sources = pickle.load(handle)
with open(path4+'SSPicker_'+version+'_4b_'+lambda_4b+'_target_gen_fpr2.pickle', 'rb') as handle:
    fpr2_cryolo_sources = pickle.load(handle)
with open(path4+'SSPicker_'+version+'_4b_'+lambda_4b+'_target_gen_rec3.pickle', 'rb') as handle:
    rec3_cryolo_sources = pickle.load(handle)
    
lambda_4c = "11114.0"
with open(path4+'SSPicker_'+version+'_4c_'+lambda_4c+'_target_gen_rec2.pickle', 'rb') as handle:
    rec2_cryolo_targets = pickle.load(handle)
with open(path4+'SSPicker_'+version+'_4c_'+lambda_4c+'_target_gen_prec2.pickle', 'rb') as handle:
    prec2_cryolo_targets = pickle.load(handle)
with open(path4+'SSPicker_'+version+'_4c_'+lambda_4c+'_target_gen_fpr2.pickle', 'rb') as handle:
    fpr2_cryolo_targets = pickle.load(handle)
with open(path4+'SSPicker_'+version+'_4c_'+lambda_4c+'_target_gen_rec3.pickle', 'rb') as handle:
    rec3_cryolo_targets = pickle.load(handle)
    
fig = p.figure()
ax = fig.gca()
ax.set_autoscale_on(False)
# ax.plot(rec2_cryolo_2wri, prec2_cryolo_2wri, label='crYOLO')
# ax.plot(rec2_boxnet_2wri, prec2_boxnet_2wri, label='Boxnet')
# ax.plot(rec2_boxnet_masked_2wri, prec2_boxnet_masked_2wri, label='Boxnet_masked')
# ax.plot(rec2_7_models_2wri, prec2_7_models_2wri, label='7 models')
ax.plot(rec2_hydra, prec2_hydra, label='HydraPicker_Sources')
ax.plot(rec2_hydra_4c, prec2_hydra_4c, label='HydraPicker_Targets')
ax.plot(rec2_boxnet_unmasked_sources, prec2_boxnet_unmasked_sources, label='BoxNet_Unmasked_Sources')
ax.plot(rec2_boxnet_masked_sources, prec2_boxnet_masked_sources, label='BoxNet_Masked_Sources')
ax.plot(rec2_boxnet_unmasked_targets, prec2_boxnet_unmasked_targets, label='BoxNet_Unmasked_Targets')
ax.plot(rec2_boxnet_masked_targets, prec2_boxnet_masked_targets, label='BoxNet_Masked_Targets')
ax.plot(rec2_cryolo_sources, prec2_cryolo_sources, label='crYOLO_Sources')
ax.plot(rec2_cryolo_targets, prec2_cryolo_targets, label='crYOLO_Targets')
ax.axis([0,1,0,1])
ax.set(xlabel='Recall', ylabel='Precision')
ax.grid()
ax.legend()

# fig = p.figure()
# ax = fig.gca()
# ax.set_autoscale_on(False)
# # ax.plot(fpr2_cryolo_2wri, rec3_cryolo_2wri, label='crYOLO')
# # ax.plot(fpr2_boxnet_2wri, rec3_boxnet_2wri, label='Boxnet')
# # ax.plot(fpr2_boxnet_masked_2wri, rec3_boxnet_masked_2wri, label='Boxnet_masked')
# # ax.plot(fpr2_7_models_2wri, rec3_7_models_2wri, label='7 models')
# # ax.plot(fpr2_hydra, rec3_hydra, label='HydraPicker')
# # ax.plot(fpr2_hydra_4c, rec3_hydra_4c, label='HydraPicker')
# # ax.plot(fpr2_boxnet_masked_sources, rec3_boxnet_masked_sources, label='BoxNet_Masked_Sources')
# # ax.plot(fpr2_boxnet_masked_sources, rec3_boxnet_masked_sources, label='BoxNet_Masked_Sources')
# # ax.plot(fpr2_boxnet_masked_targets, rec3_boxnet_masked_targets, label='BoxNet_Masked_Targets')

# ax.axis([0,1,0,1])
# ax.set(xlabel='False-Positive Rate', ylabel='Recall')
# ax.grid()
# ax.legend()

# %%
prec2_boxnet_masked_targets[2500:]
# Out:
# [0.8012,
#  0.8009592326139089,
#  0.8009592326139089,
#  0.8007984031936127,
#  0.8007984031936127,
#  0.8007984031936127,
#  0.8007145692735212,
#  0.8007145692735212,
#  0.8007145692735212,
#  0.8007145692735212,
#  0.8007145692735212,
#  0.8007145692735212,
#  0.8007145692735212,
#  0.8007145692735212,
#  0.8007145692735212,
#  0.8007145692735212,
#  0.8007145692735212,
#  0.8007145692735212,
#  0.8007145692735212,
#  0.8007145692735212,
#  0.8003968253968254,
#  0.8003169572107766,
#  0.8003169572107766,
#  0.8003169572107766,
#  0.8003169572107766,
#  0.8,
#  0.7996832937450514,
#  0.7994462025316456,
#  0.7994462025316456,
#  0.7993680884676145,
#  0.7993680884676145,
#  0.7993680884676145,
#  0.7993680884676145]

# %% [markdown]
# # 5w3l zero-shot

# %%
version = "29_6"

lambda_4b = "2001.2"
with open(path4+'SSPicker_'+version+'_4b_'+lambda_4b+'_target_gen_rec2.pickle', 'rb') as handle:
    rec2_cryolo_5w3l_z = pickle.load(handle)
with open(path4+'SSPicker_'+version+'_4b_'+lambda_4b+'_target_gen_prec2.pickle', 'rb') as handle:
    prec2_cryolo_5w3l_z = pickle.load(handle)
with open(path4+'SSPicker_'+version+'_4b_'+lambda_4b+'_target_gen_fpr2.pickle', 'rb') as handle:
    fpr2_cryolo_5w3l_z = pickle.load(handle)
with open(path4+'SSPicker_'+version+'_4b_'+lambda_4b+'_target_gen_rec3.pickle', 'rb') as handle:
    rec3_cryolo_5w3l_z = pickle.load(handle) 

# lambda_4c = "1002.1"
# with open(path4+'SSPicker_'+version+'_4c_'+lambda_4c+'_target_gen_rec2.pickle', 'rb') as handle:
#     rec2_boxnet_2wri = pickle.load(handle)
# with open(path4+'SSPicker_'+version+'_4c_'+lambda_4c+'_target_gen_prec2.pickle', 'rb') as handle:
#     prec2_boxnet_2wri = pickle.load(handle)
# with open(path4+'SSPicker_'+version+'_4c_'+lambda_4c+'_target_gen_fpr2.pickle', 'rb') as handle:
#     fpr2_boxnet_2wri = pickle.load(handle)
# with open(path4+'SSPicker_'+version+'_4c_'+lambda_4c+'_target_gen_rec3.pickle', 'rb') as handle:
#     rec3_boxnet_2wri = pickle.load(handle)
    
lambda_4b = "2003.2"
with open(path4+'SSPicker_'+version+'_4b_'+lambda_4b+'_target_gen_rec2.pickle', 'rb') as handle:
    rec2_boxnet_masked_5w3l_z = pickle.load(handle)
with open(path4+'SSPicker_'+version+'_4b_'+lambda_4b+'_target_gen_prec2.pickle', 'rb') as handle:
    prec2_boxnet_masked_5w3l_z = pickle.load(handle)
with open(path4+'SSPicker_'+version+'_4b_'+lambda_4b+'_target_gen_fpr2.pickle', 'rb') as handle:
    fpr2_boxnet_masked_5w3l_z = pickle.load(handle)
with open(path4+'SSPicker_'+version+'_4b_'+lambda_4b+'_target_gen_rec3.pickle', 'rb') as handle:
    rec3_boxnet_masked_5w3l_z = pickle.load(handle) 

# lambda_4c = "1004.1"
# with open(path4+'SSPicker_'+version+'_4c_'+lambda_4c+'_target_gen_rec2.pickle', 'rb') as handle:
#     rec2_7_models_2wri = pickle.load(handle)
# with open(path4+'SSPicker_'+version+'_4c_'+lambda_4c+'_target_gen_prec2.pickle', 'rb') as handle:
#     prec2_7_models_2wri = pickle.load(handle)
# with open(path4+'SSPicker_'+version+'_4c_'+lambda_4c+'_target_gen_fpr2.pickle', 'rb') as handle:
#     fpr2_7_models_2wri = pickle.load(handle)
# with open(path4+'SSPicker_'+version+'_4c_'+lambda_4c+'_target_gen_rec3.pickle', 'rb') as handle:
#     rec3_7_models_2wri = pickle.load(handle) 
    
lambda_4b = "2005.2"
with open(path4+'SSPicker_'+version+'_4b_'+lambda_4b+'_target_gen_rec2.pickle', 'rb') as handle:
    rec2_hydra_5w3l_z = pickle.load(handle)
with open(path4+'SSPicker_'+version+'_4b_'+lambda_4b+'_target_gen_prec2.pickle', 'rb') as handle:
    prec2_hydra_5w3l_z = pickle.load(handle)
with open(path4+'SSPicker_'+version+'_4b_'+lambda_4b+'_target_gen_fpr2.pickle', 'rb') as handle:
    fpr2_hydra_5w3l_z = pickle.load(handle)
with open(path4+'SSPicker_'+version+'_4b_'+lambda_4b+'_target_gen_rec3.pickle', 'rb') as handle:
    rec3_hydra_5w3l_z = pickle.load(handle)


fig = p.figure()
ax = fig.gca()
ax.set_autoscale_on(False)
ax.plot(rec2_cryolo_5w3l_z, prec2_cryolo_5w3l_z, label='crYOLO')
# ax.plot(rec2_boxnet_2wri, prec2_boxnet_2wri, label='Boxnet')
ax.plot(rec2_boxnet_masked_5w3l_z, prec2_boxnet_masked_5w3l_z, label='BoxNet_masked')
# ax.plot(rec2_7_models_2wri, prec2_7_models_2wri, label='7 models')
ax.plot(rec2_hydra_5w3l_z, prec2_hydra_5w3l_z, label='HydraPicker')
ax.axis([0,1,0,1])
ax.set(xlabel='Recall', ylabel='Precision')
ax.grid()
ax.legend()

fig = p.figure()
ax = fig.gca()
ax.set_autoscale_on(False)
ax.plot(fpr2_cryolo_5w3l_z, rec3_cryolo_5w3l_z, label='crYOLO')
# ax.plot(fpr2_boxnet_2wri, rec3_boxnet_2wri, label='Boxnet')
ax.plot(fpr2_boxnet_masked_5w3l_z, rec3_boxnet_masked_5w3l_z, label='BoxNet_masked')
# ax.plot(fpr2_7_models_2wri, rec3_7_models_2wri, label='7 models')
ax.plot(fpr2_hydra_5w3l_z, rec3_hydra_5w3l_z, label='HydraPicker')
ax.axis([0,1,0,1])
ax.set(xlabel='False-Positive Rate', ylabel='Recall')
ax.grid()
ax.legend()

# %% [markdown]
# # 10078

# %%
version = "29_6"

lambda_4b = "2001.1"
with open(path4+'SSPicker_'+version+'_4b_'+lambda_4b+'_target_gen_rec2.pickle', 'rb') as handle:
    rec2_cryolo_5foj = pickle.load(handle)
with open(path4+'SSPicker_'+version+'_4b_'+lambda_4b+'_target_gen_prec2.pickle', 'rb') as handle:
    prec2_cryolo_5foj = pickle.load(handle)
with open(path4+'SSPicker_'+version+'_4b_'+lambda_4b+'_target_gen_fpr2.pickle', 'rb') as handle:
    fpr2_cryolo_5foj = pickle.load(handle)
with open(path4+'SSPicker_'+version+'_4b_'+lambda_4b+'_target_gen_rec3.pickle', 'rb') as handle:
    rec3_cryolo_5foj = pickle.load(handle) 

# lambda_4c = "1002.1"
# with open(path4+'SSPicker_'+version+'_4c_'+lambda_4c+'_target_gen_rec2.pickle', 'rb') as handle:
#     rec2_boxnet_2wri = pickle.load(handle)
# with open(path4+'SSPicker_'+version+'_4c_'+lambda_4c+'_target_gen_prec2.pickle', 'rb') as handle:
#     prec2_boxnet_2wri = pickle.load(handle)
# with open(path4+'SSPicker_'+version+'_4c_'+lambda_4c+'_target_gen_fpr2.pickle', 'rb') as handle:
#     fpr2_boxnet_2wri = pickle.load(handle)
# with open(path4+'SSPicker_'+version+'_4c_'+lambda_4c+'_target_gen_rec3.pickle', 'rb') as handle:
#     rec3_boxnet_2wri = pickle.load(handle)
    
lambda_4b = "2003.1"
with open(path4+'SSPicker_'+version+'_4b_'+lambda_4b+'_target_gen_rec2.pickle', 'rb') as handle:
    rec2_boxnet_masked_5foj = pickle.load(handle)
with open(path4+'SSPicker_'+version+'_4b_'+lambda_4b+'_target_gen_prec2.pickle', 'rb') as handle:
    prec2_boxnet_masked_5foj = pickle.load(handle)
with open(path4+'SSPicker_'+version+'_4b_'+lambda_4b+'_target_gen_fpr2.pickle', 'rb') as handle:
    fpr2_boxnet_masked_5foj = pickle.load(handle)
with open(path4+'SSPicker_'+version+'_4b_'+lambda_4b+'_target_gen_rec3.pickle', 'rb') as handle:
    rec3_boxnet_masked_5foj = pickle.load(handle) 

# lambda_4c = "1004.1"
# with open(path4+'SSPicker_'+version+'_4c_'+lambda_4c+'_target_gen_rec2.pickle', 'rb') as handle:
#     rec2_7_models_2wri = pickle.load(handle)
# with open(path4+'SSPicker_'+version+'_4c_'+lambda_4c+'_target_gen_prec2.pickle', 'rb') as handle:
#     prec2_7_models_2wri = pickle.load(handle)
# with open(path4+'SSPicker_'+version+'_4c_'+lambda_4c+'_target_gen_fpr2.pickle', 'rb') as handle:
#     fpr2_7_models_2wri = pickle.load(handle)
# with open(path4+'SSPicker_'+version+'_4c_'+lambda_4c+'_target_gen_rec3.pickle', 'rb') as handle:
#     rec3_7_models_2wri = pickle.load(handle) 
    
lambda_4b = "2005.1"
with open(path4+'SSPicker_'+version+'_4b_'+lambda_4b+'_target_gen_rec2.pickle', 'rb') as handle:
    rec2_hydra_5foj = pickle.load(handle)
with open(path4+'SSPicker_'+version+'_4b_'+lambda_4b+'_target_gen_prec2.pickle', 'rb') as handle:
    prec2_hydra_5foj = pickle.load(handle)
with open(path4+'SSPicker_'+version+'_4b_'+lambda_4b+'_target_gen_fpr2.pickle', 'rb') as handle:
    fpr2_hydra_5foj = pickle.load(handle)
with open(path4+'SSPicker_'+version+'_4b_'+lambda_4b+'_target_gen_rec3.pickle', 'rb') as handle:
    rec3_hydra_5foj = pickle.load(handle)


fig = p.figure()
ax = fig.gca()
ax.set_autoscale_on(False)
ax.plot(rec2_cryolo_5foj, prec2_cryolo_5foj, label='crYOLO')
# ax.plot(rec2_boxnet_2wri, prec2_boxnet_2wri, label='Boxnet')
ax.plot(rec2_boxnet_masked_5foj, prec2_boxnet_masked_5foj, label='BoxNet_masked')
# ax.plot(rec2_7_models_2wri, prec2_7_models_2wri, label='7 models')
ax.plot(rec2_hydra_5foj, prec2_hydra_5foj, label='HydraPicker')
ax.axis([0,1,0,1])
ax.set(xlabel='Recall', ylabel='Precision')
ax.grid()
ax.legend()

fig = p.figure()
ax = fig.gca()
ax.set_autoscale_on(False)
ax.plot(fpr2_cryolo_5foj, rec3_cryolo_5foj, label='crYOLO')
# ax.plot(fpr2_boxnet_2wri, rec3_boxnet_2wri, label='Boxnet')
ax.plot(fpr2_boxnet_masked_5foj, rec3_boxnet_masked_5foj, label='BoxNet_masked')
# ax.plot(fpr2_7_models_2wri, rec3_7_models_2wri, label='7 models')
ax.plot(fpr2_hydra_5foj, rec3_hydra_5foj, label='HydraPicker')
ax.axis([0,1,0,1])
ax.set(xlabel='False-Positive Rate', ylabel='Recall')
ax.grid()
ax.legend()

# %% [markdown]
# # 5foj

# %%
version = "29_6"

lambda_4b = "2001.3"
with open(path4+'SSPicker_'+version+'_4b_'+lambda_4b+'_target_gen_rec2.pickle', 'rb') as handle:
    rec2_cryolo_10078 = pickle.load(handle)
with open(path4+'SSPicker_'+version+'_4b_'+lambda_4b+'_target_gen_prec2.pickle', 'rb') as handle:
    prec2_cryolo_10078 = pickle.load(handle)
with open(path4+'SSPicker_'+version+'_4b_'+lambda_4b+'_target_gen_fpr2.pickle', 'rb') as handle:
    fpr2_cryolo_10078 = pickle.load(handle)
with open(path4+'SSPicker_'+version+'_4b_'+lambda_4b+'_target_gen_rec3.pickle', 'rb') as handle:
    rec3_cryolo_10078 = pickle.load(handle) 

# lambda_4c = "1002.1"
# with open(path4+'SSPicker_'+version+'_4c_'+lambda_4c+'_target_gen_rec2.pickle', 'rb') as handle:
#     rec2_boxnet_2wri = pickle.load(handle)
# with open(path4+'SSPicker_'+version+'_4c_'+lambda_4c+'_target_gen_prec2.pickle', 'rb') as handle:
#     prec2_boxnet_2wri = pickle.load(handle)
# with open(path4+'SSPicker_'+version+'_4c_'+lambda_4c+'_target_gen_fpr2.pickle', 'rb') as handle:
#     fpr2_boxnet_2wri = pickle.load(handle)
# with open(path4+'SSPicker_'+version+'_4c_'+lambda_4c+'_target_gen_rec3.pickle', 'rb') as handle:
#     rec3_boxnet_2wri = pickle.load(handle)
    
lambda_4b = "2003.3"
with open(path4+'SSPicker_'+version+'_4b_'+lambda_4b+'_target_gen_rec2.pickle', 'rb') as handle:
    rec2_boxnet_masked_10078 = pickle.load(handle)
with open(path4+'SSPicker_'+version+'_4b_'+lambda_4b+'_target_gen_prec2.pickle', 'rb') as handle:
    prec2_boxnet_masked_10078 = pickle.load(handle)
with open(path4+'SSPicker_'+version+'_4b_'+lambda_4b+'_target_gen_fpr2.pickle', 'rb') as handle:
    fpr2_boxnet_masked_10078 = pickle.load(handle)
with open(path4+'SSPicker_'+version+'_4b_'+lambda_4b+'_target_gen_rec3.pickle', 'rb') as handle:
    rec3_boxnet_masked_10078 = pickle.load(handle) 

# lambda_4c = "1004.1"
# with open(path4+'SSPicker_'+version+'_4c_'+lambda_4c+'_target_gen_rec2.pickle', 'rb') as handle:
#     rec2_7_models_2wri = pickle.load(handle)
# with open(path4+'SSPicker_'+version+'_4c_'+lambda_4c+'_target_gen_prec2.pickle', 'rb') as handle:
#     prec2_7_models_2wri = pickle.load(handle)
# with open(path4+'SSPicker_'+version+'_4c_'+lambda_4c+'_target_gen_fpr2.pickle', 'rb') as handle:
#     fpr2_7_models_2wri = pickle.load(handle)
# with open(path4+'SSPicker_'+version+'_4c_'+lambda_4c+'_target_gen_rec3.pickle', 'rb') as handle:
#     rec3_7_models_2wri = pickle.load(handle) 
    
lambda_4b = "2005.3"
with open(path4+'SSPicker_'+version+'_4b_'+lambda_4b+'_target_gen_rec2.pickle', 'rb') as handle:
    rec2_hydra_10078 = pickle.load(handle)
with open(path4+'SSPicker_'+version+'_4b_'+lambda_4b+'_target_gen_prec2.pickle', 'rb') as handle:
    prec2_hydra_10078 = pickle.load(handle)
with open(path4+'SSPicker_'+version+'_4b_'+lambda_4b+'_target_gen_fpr2.pickle', 'rb') as handle:
    fpr2_hydra_10078 = pickle.load(handle)
with open(path4+'SSPicker_'+version+'_4b_'+lambda_4b+'_target_gen_rec3.pickle', 'rb') as handle:
    rec3_hydra_10078 = pickle.load(handle)


fig = p.figure()
ax = fig.gca()
ax.set_autoscale_on(False)
ax.plot(rec2_cryolo_10078, prec2_cryolo_10078, label='crYOLO')
# ax.plot(rec2_boxnet_2wri, prec2_boxnet_2wri, label='Boxnet')
ax.plot(rec2_boxnet_masked_10078, prec2_boxnet_masked_10078, label='BoxNet_masked')
# ax.plot(rec2_7_models_2wri, prec2_7_models_2wri, label='7 models')
ax.plot(rec2_hydra_10078, prec2_hydra_10078, label='HydraPicker')
ax.axis([0,1,0,1])
ax.set(xlabel='Recall', ylabel='Precision')
ax.grid()
ax.legend()

fig = p.figure()
ax = fig.gca()
ax.set_autoscale_on(False)
ax.plot(fpr2_cryolo_10078, rec3_cryolo_10078, label='crYOLO')
# ax.plot(fpr2_boxnet_2wri, rec3_boxnet_2wri, label='Boxnet')
ax.plot(fpr2_boxnet_masked_10078, rec3_boxnet_masked_10078, label='BoxNet_masked')
# ax.plot(fpr2_7_models_2wri, rec3_7_models_2wri, label='7 models')
ax.plot(fpr2_hydra_10078, rec3_hydra_10078, label='HydraPicker')
ax.axis([0,1,0,1])
ax.set(xlabel='False-Positive Rate', ylabel='Recall')
ax.grid()
ax.legend()

# %%
version = "29_6"
lambda_4c = "888.0"
with open(path4+'SSPicker_'+version+'_4c_'+lambda_4c+'_target_gen_rec2.pickle', 'rb') as handle:
    rec2_4c_29_6_single_source_single_target = pickle.load(handle)
with open(path4+'SSPicker_'+version+'_4c_'+lambda_4c+'_target_gen_prec2.pickle', 'rb') as handle:
    prec2_4c_29_6_single_source_single_target = pickle.load(handle)
with open(path4+'SSPicker_'+version+'_4c_'+lambda_4c+'_target_gen_fpr2.pickle', 'rb') as handle:
    fpr2_4c_29_6_single_source_single_target = pickle.load(handle)
with open(path4+'SSPicker_'+version+'_4c_'+lambda_4c+'_target_gen_rec3.pickle', 'rb') as handle:
    rec3_4c_29_6_single_source_single_target = pickle.load(handle)
    
lambda_4c = "888.1"
with open(path4+'SSPicker_'+version+'_4c_'+lambda_4c+'_target_gen_rec2.pickle', 'rb') as handle:
    rec2_4c_29_6_multi_source_single_target = pickle.load(handle)
with open(path4+'SSPicker_'+version+'_4c_'+lambda_4c+'_target_gen_prec2.pickle', 'rb') as handle:
    prec2_4c_29_6_multi_source_single_target = pickle.load(handle)
with open(path4+'SSPicker_'+version+'_4c_'+lambda_4c+'_target_gen_fpr2.pickle', 'rb') as handle:
    fpr2_4c_29_6_multi_source_single_target = pickle.load(handle)
with open(path4+'SSPicker_'+version+'_4c_'+lambda_4c+'_target_gen_rec3.pickle', 'rb') as handle:
    rec3_4c_29_6_multi_source_single_target = pickle.load(handle)

fig = p.figure()
ax = fig.gca()
ax.set_autoscale_on(False)
# ax.plot(rec2_5b_401, prec2_5b_401, label='crYOLO-old')
# ax.plot(rec2_4c_29_1_cryolo_v1, prec2_4c_29_1_cryolo_v1, label='crYOLO_v1')
# ax.plot(rec2_4c_29_1_cryolo_v1_new, prec2_4c_29_1_cryolo_v1_new, label='crYOLO')
# ax.plot(rec2_4c_29_1_cryolo_v1_filtered, prec2_4c_29_1_cryolo_v1_filtered, label='crYOLO-v1_filtered')
# ax.plot(rec2_4c_29_1_cryolo_v2, prec2_4c_29_1_cryolo_v2, label='crYOLO-v2')
# ax.plot(rec2_4c_29_1_cryolo_v2_filtered, prec2_4c_29_1_cryolo_v2_filtered, label='crYOLO-v2_filtered')
# ax.plot(rec2_5b_200, prec2_5b_200, label='Boxnet-old')
# ax.plot(rec2_4c_29_1_boxnet_unmasked, prec2_4c_29_1_boxnet_unmasked, label='Boxnet_unmasked_old')
# ax.plot(rec2_4c_29_1_boxnet_unmasked2, prec2_4c_29_1_boxnet_unmasked2, label='Boxnet')
# ax.plot(rec2_4c_29_1_boxnet_masked2, prec2_4c_29_1_boxnet_masked2, label='Boxnet_masked')
# ax.plot(rec2_5b_300, prec2_5b_300, label='7 models')
# ax.plot(rec2_5b_300_1, prec2_5b_300_1, label='7 models')
# ax.plot(rec2_4c, prec2_4c, label='HydraPicker-old')
# ax.plot(rec2_4c_29_1, prec2_4c_29_1, label='HydraPicker_old')
# ax.plot(rec2_4c_29_6, prec2_4c_29_6, label='HydraPicker_old')
ax.plot(rec2_4c_29_6_single_source_single_target, prec2_4c_29_6_single_source_single_target, label='single_source_single_target')
ax.plot(rec2_4c_29_6_multi_source_single_target, prec2_4c_29_6_multi_source_single_target, label='multi_source_single_target')
ax.axis([0,1,0,1])
ax.set(xlabel='Recall', ylabel='Precision')
ax.grid()
ax.legend()

fig = p.figure()
ax = fig.gca()
ax.set_autoscale_on(False)
# ax.plot(fpr2_5b_401, rec3_5b_401, label='crYOLO-old')
# ax.plot(fpr2_4c_29_1_cryolo_v1, rec3_4c_29_1_cryolo_v1, label='crYOLO_v1')
# ax.plot(fpr2_4c_29_1_cryolo_v1_new, rec3_4c_29_1_cryolo_v1_new, label='crYOLO')
# ax.plot(fpr2_4c_29_1_cryolo_v1_filtered, rec3_4c_29_1_cryolo_v1_filtered, label='crYOLO-v1_filtered')
# ax.plot(fpr2_4c_29_1_cryolo_v2, rec3_4c_29_1_cryolo_v2, label='crYOLO-v2')
# ax.plot(fpr2_4c_29_1_cryolo_v2_filtered, rec3_4c_29_1_cryolo_v2_filtered, label='crYOLO-v2_filtered')
# ax.plot(fpr2_5b_200, rec3_5b_200, label='Boxnet-old')
# ax.plot(fpr2_4c_29_1_boxnet_unmasked, rec3_4c_29_1_boxnet_unmasked, label='Boxnet_unmasked_old')
# ax.plot(fpr2_4c_29_1_boxnet_unmasked2, rec3_4c_29_1_boxnet_unmasked2, label='Boxnet')
# ax.plot(fpr2_4c_29_1_boxnet_masked2, rec3_4c_29_1_boxnet_masked2, label='Boxnet_masked')
# ax.plot(fpr2_5b_300, rec3_5b_300, label='7 models')
# ax.plot(fpr2_5b_300_1, rec3_5b_300_1, label='7 models')
# ax.plot(fpr2_4c, rec3_4c, label='HydraPicker-old')
# ax.plot(fpr2_4c_29_1, rec3_4c_29_1, label='HydraPicker_old')
# ax.plot(fpr2_4c_29_6, rec3_4c_29_6, label='HydraPicker_old')
ax.plot(fpr2_4c_29_6_single_source_single_target, rec3_4c_29_6_single_source_single_target, label='single_source_single_target')
ax.plot(fpr2_4c_29_6_multi_source_single_target, rec3_4c_29_6_multi_source_single_target, label='multi_source_single_target')
ax.axis([0,1,0,1])
ax.set(xlabel='False-Positive Rate', ylabel='Recall')
ax.grid()
ax.legend()
